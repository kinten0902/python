# %%
# -*- coding: utf-8 -*-
# %matplotlib inline
import numpy as np
import pandas as pd
from collections import Counter
import re
import pickle
import MeCab
mc = MeCab.Tagger("-Ochasen")

# %%
new_excel = pd.ExcelFile("data/excel2/new_data.xlsx")
sheet_name = new_excel.sheet_names[0]
new_df = new_excel.parse(sheet_name)

# %%
new_df
# Out:
#          id  reply  group_id  cname  \
# 0     10730      0         1    飼育係
# 1     10749      0         1     ドラ
# 2     10754      0         1    海の日
# 3     10849      0         1    飼育係
# 4     10903      0         1    飼育係
# 5     10908      0         1     ドラ
# 6     10923      0         1    飼育係
# 7     11065      0         1     ドラ
# 8     11070      0         1     ドラ
# 9     11135      0         1    海の日
# 10    11385      0         1    海の日
# 11    11406      0         1    飼育係
# 12    11414      0         1    飼育係
# 13    11449      0         1     ドラ
# 14    11503      0         1    飼育係
# 15    11640  11503         1     ドラ
# 16    11684      0         1    飼育係
# 17    11701      0         1    海の日
# 18    11917      0         1     ドラ
# 19    12003      0         1    飼育係
# 20    12043      0         1     ドラ
# 21    12049      0         1    海の日
# 22    12053      0         1     ドラ
# 23    12171      0         1    飼育係
# 24    12205  12171         1     ドラ
# 25    12216      0         1    海の日
# 26    12326      0         1    海の日
# 27    12353      0         1     ドラ
# 28    12408      0         1    飼育係
# 29    12496      0         1     ドラ
# ...     ...    ...       ...    ...
# 2713  11629  11594        46   イイダイ
# 2714  11707  11629        46  ジャスミン
# 2715  11764      0        46  ジャスミン
# 2716  11795  11764        46   イイダイ
# 2717  11804      0        46     アキ
# 2718  11861  11804        46  ジャスミン
# 2719  11912  11861        46   イイダイ
# 2720  11984      0        46   イイダイ
# 2721  11986      0        46     アキ
# 2722  11998  11986        46   イイダイ
# 2723  12014  11986        46  ジャスミン
# 2724  12046      0        46  ジャスミン
# 2725  12067  12046        46   イイダイ
# 2726  12250      0        46   イイダイ
# 2727  12291      0        46     アキ
# 2728  12315  12291        46   イイダイ
# 2729  12335      0        46     アキ
# 2730  12360  12250        46  ジャスミン
# 2731  12564  12360        46     アキ
# 2732  12616  12564        46  ジャスミン
# 2733  12660  12616        46   イイダイ
# 2734  12674  12660        46  ジャスミン
# 2735  12676  12674        46     アキ
# 2736  12794      0        46  ジャスミン
# 2737  12807      0        46     アキ
# 2738  12817  12794        46   イイダイ
# 2739  12882      0        46  ジャスミン
# 2740  12919  12882        46   イイダイ
# 2741  12950      0        46     アキ
# 2742  13002  12950        46  ジャスミン
#
#                                                    body label
# 0                                             よろしくー\n\n   NAN
# 1                                           よろしくお願いします～   NAN
# 2                                           よろしくお願いしまーす   NAN
# 3                                なんかやり方違うｗｗｗｗｗｗｗｗｗｗｗｗｗｗ   NAN
# 4                                      拝見しましたが特に問題はないです   NAN
# 5                                     とりあえずこのまま進めてみますか？   NAN
# 6                                         そうしてくれると助かります   NAN
# 7              お二人のワード拝見しました。\n\n内容については特に疑問点はありませんでした。   NAN
# 8              お二人のワード拝見しました。\n\n内容については特に疑問点はありませんでした。   NAN
# 9                                         私も特にありませんでした。   NAN
# 10                                         課題３そろそろやります？   NAN
# 11              新番組の内容としては幼児にAR機能を体験させるという番組にしてはどうでしょうか   NAN
# 12                            キャラクターが出てくるなんて子供には受けそうですし   NAN
# 13                 AR機能の体験とありますが、それはどのような教育目的の番組なのでしょうか   NAN
# 14                 つくってあそぼであった学習での造形の魅力を更に引き立たせる感じでしょうか   NAN
# 15    > つくってあそぼであった学習での造形の魅力を更に引き立たせる感じでしょうか\n\nつくって...   NAN
# 16                                  そうなんですか理解してなくてすみません   NAN
# 17                          ARを使うのならば造形より勉強のほうが使えそうですね。   NAN
# 18    教育番組でAR機能を使用するとなると、どのような風に使用するのかわからないのですがどのように...   NAN
# 19          ARの進めていくと結構時間かかりそうなのでARから離れて違う方面で考えていきませんか？   NAN
# 20                                                そうですね   NAN
# 21                                 そうですね。一旦ARから離れてみましょう   NAN
# 22    まずは対象者や学習課題から決めていきませんか。学習課題を決めてからのほうが番組内容が考えやす...   NAN
# 23    年齢対象は幼児が対象で学習課題としては子供だとマナーを知らない子が多いと思うのでそこの視点で...   NAN
# 24    > 年齢対象は幼児が対象で学習課題としては子供だとマナーを知らない子が多いと思うのでそこの視...   NAN
# 25                                                良いですね   NAN
# 26                                      番組内容はどんな感じですかね？   NAN
# 27    番組内容はどうしましょうか？\n\n自分としてはマナーについてということと子供に教えるという...   NAN
# 28                   いいですね、正解すると何かおかしなどがもらえたりすると良いと思います   NAN
# 29                                   とりあえず今の状態で提出しましょうか   NAN
# ...                                                 ...   ...
# 2713  > 多分共通してるのは子供が喜ぶような可愛いキャラクターがいることだと思います\n\n> 動...   NAN
# 2714  > > 多分共通してるのは子供が喜ぶような可愛いキャラクターがいることだと思います\n\n>...   NAN
# 2715  最近は子供がスマホを利用することが多くなってきたので、ネットのモラルについて学ぶ作品とかはど...   NAN
# 2716  > 最近は子供がスマホを利用することが多くなってきたので、ネットのモラルについて学ぶ作品とか...   NAN
# 2717                  いいと思いますよ！\n\nそれをどんな感じに番組にしていくかですね   NAN
# 2718                            やはり動物キャラを出すのが有効ですかね\n\n   NAN
# 2719        > やはり動物キャラを出すのが有効ですかね\n\n> 何の動物にするかですね。\n\n   NAN
# 2720                                対象者はどの層をターゲットにしますか？   NAN
# 2721                対象者は小学校低学年あたりぐらいの子たちを対象にするのはどうでしょう？   NAN
# 2722  > 対象者は小学校低学年あたりぐらいの子たちを対象にするのはどうでしょう？\n\nありですね...   NAN
# 2723               スマホを持ち始めるのが早くてそれくらいだと思うので良いと思います\n\n   NAN
# 2724           出す動物ですが、ネットの危険を取り締まる犬のお巡りさんとか、どうでしょう？(笑)   NAN
# 2725  > 出す動物ですが、ネットの危険を取り締まる犬のお巡りさんとか、どうでしょう？(笑)\n\n...   NAN
# 2726                          教育番組の内容はスマホのどの問題を取り上げますか？   NAN
# 2727                          あまり時間ないんで簡単まとめる感じでいいですかね？   NAN
# 2728        > あまり時間ないんで簡単まとめる感じでいいですかね？\n\n良いと思います。\n\n   NAN
# 2729     あとタイトルは一つの単語になって語呂がいい言葉がおぼえやすくていいと思いますがどうでしょう？   NAN
# 2730  取り上げる問題は、依存しすぎて現実に支障が出てしまうこととか、親に無断で課金してしまうことと...   NAN
# 2731  > 取り上げる問題は、依存しすぎて現実に支障が出てしまうこととか、親に無断で課金してしまうこ...   NAN
# 2732                  安直ですけど、「ネットの中のお巡りさん」とか。ちょっと長いですかね   NAN
# 2733  > 安直ですけど、「ネットの中のお巡りさん」とか。ちょっと長いですかね\n\nありですね。\n\n   NAN
# 2734                               じゃあ取り敢えずこれで一回出しておきます   NAN
# 2735                   > じゃあ取り敢えずこれで一回出しておきます\n\nお願いします   NAN
# 2736                                              いますか？   NAN
# 2737                                               いますよ   NAN
# 2738                             > いますか？\n\nいます\n\n\n\n   NAN
# 2739                          一応前回提出したんですけど、何か追加したりします？   NAN
# 2740     > 一応前回提出したんですけど、何か追加したりします？\n\n特にはないです\n\n\n\n   NAN
# 2741                       ある程度完成しているのでそのままだしてもいいとおもいます   NAN
# 2742                                               了解です   NAN
#
# [2743 rows x 6 columns]

# %%
print(type(new_df))
print(Counter(new_df['label']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Counter({'NAN': 2743})

# %%
# 重複投稿の排除
# new_df = new_df.drop_duplicates(subset=['cname', 'body'])
# print(Counter(new_df['label']))

# %%
new_data = new_df.values

id = 0
reply = 1
group_id = 2
cname = 3
body = 4
label = 5

# %%
def preprocess(xs, trim_citation=False):
    zs = [""] * len(xs)
    '''全角空白'''
    for i, l in enumerate(xs):
        xs[i] = re.sub('　', ' ', str(l))
    '''多重引用'''
    for i, l in enumerate(xs):
        xs[i] = re.sub('＆ｇｔ；', '＞', l)
    '''引用部分は除外'''
    count_refer = 0
    for i, l in enumerate(xs):
        sen = ""
        have_refer = 1
        for x in l.split('\n'):
            if len(x) == 0:
                continue
            elif x[0].encode('utf-8') == '＞'.encode('utf-8'):
                have_refer = 1
                x = x[1:]
                if len(x) > 0 and x[0].encode('utf-8') != '＞'.encode('utf-8') and \
                        x[0:2].encode('utf-8') != ' ＞'.encode('utf-8') and x != ' ':
                    if trim_citation:
                        zs[i] += x + '\n'
                    else:
                        sen = sen + "＞ " + x + '\n'
                continue
            else:
                sen = sen + x + '\n'
        xs[i] = sen.strip()
        count_refer += have_refer
    '''顔文字'''
    pat = re.compile('（[^ぁ-んァ-ン一-龠]+?）', re.U)
    for i, l in enumerate(xs):
        xs[i] = re.sub(pat, ' KAOMOJI ', l)
    '''日本語及び記号{？！ー〜。、} のみ有効'''
    pat = re.compile('[^＞ Ａ-Ｚａ-ｚ０-９ぁ-んァ-ン一-龠？！ー〜。、\n]+?', re.U)
    for i, l in enumerate(xs):
        xs[i] = re.sub(pat, '', l)
    '''記号繰り返し'''
    pat_1 = re.compile('[ｗ]{1,}', re.U)
    pat_2 = re.compile('[？]{1,}', re.U)
    pat_3 = re.compile('[！]{1,}', re.U)
    pat_4 = re.compile('[～]{1,}', re.U)
    pat_5 = re.compile('[ー]{1,}', re.U)
    pat_6 = re.compile('[。]{1,}', re.U)

    for i, l in enumerate(xs):
        l = re.sub(pat_1, 'ｗ', l)
        l = re.sub(pat_2, '？', l)
        l = re.sub(pat_3, '！', l)
        l = re.sub(pat_4, '～', l)
        l = re.sub(pat_5, 'ー', l)
        l = re.sub(pat_6, '。', l)
        xs[i] = l

    if trim_citation:
        return zs
    else:
        return None

# %%
def make_xs(orig, trim_citation=False, use_seq2seq=False):

    tmp = np.copy(orig)
    xs = tmp[:, body]
    zs = preprocess(xs, trim_citation=(trim_citation or use_seq2seq))

    if use_seq2seq:
        tmp_prev = np.roll(tmp, 1, axis=0)
        tmp_prev[0, 0] = ""
        ts = tmp[:, [1, 2]]
        xs_prev = tmp_prev[:, body]

        for i in range(len(tmp)):
            if tmp[i, group_id] != tmp_prev[i, group_id]:  # group が異なる
                xs_prev[i] = ""
        preprocess(xs_prev, trim_citation=True)

        for i in range(len(xs)):
            replay_to = tmp[i, 2]
            if zs[i] != "":
                xs_prev[i] = zs[i]
            elif replay_to != -1:
                a = xs[:i][tmp[:i, 1] == replay_to]
                if len(a) != 0:
                    xs_prev[i] = a[-1]

        return xs, xs_prev
    else:
        return xs

# %%
def get_doc(xs):
    doc = []
    for ll in xs:
        sen = []
        for l in ll.split('\n'):
            for w in mc.parse(l).split('\n'):
                mx = w.split('\t')
                if len(mx[0]) > 0:
                    sen.append(mx[0])
        doc.append(sen)
    return doc

# %%
new_xs,new_xs_pre = make_xs(new_data, trim_citation=True, use_seq2seq=True)
new_doc = get_doc(new_xs)
new_doc_pre = get_doc(new_xs_pre)

# %%
for i in new_doc[:10]:
    print(" ".join(i))
# Out:
# よろしく ー EOS
# よろしく お願い し ます EOS
# よろしく お願い しま ー す EOS
# なんか やり方 違う ｗ EOS
# 拝見 し まし た が 特に 問題 は ない です EOS
# とりあえず この まま 進め て み ます か ？ EOS
# そう し て くれる と 助かり ます EOS
# お 二 人 の ワード 拝見 し まし た 。 EOS 内容 について は 特に 疑問 点 は あり ませ ん でし た 。 EOS
# お 二 人 の ワード 拝見 し まし た 。 EOS 内容 について は 特に 疑問 点 は あり ませ ん でし た 。 EOS
# 私 も 特に あり ませ ん でし た 。 EOS

# %%
wd_set = Counter([x for sen in new_doc + new_doc_pre for x in sen])
wd_ary = np.array(list(wd_set.keys()))
wd_cnt = np.array(list(wd_set.values()))
wd_ary = wd_ary[np.argsort(wd_cnt)[::-1]]
wd_cnt.sort()
wd_cnt = wd_cnt[::-1]
wd_to_id = {wd: i for i, wd in enumerate(wd_ary)}
lb_to_id = {lb: i for i, lb in enumerate({x for x in new_data[:, label]})}
id_to_wd = {wd_to_id[wd]: wd for wd in wd_to_id.keys()}
id_to_lb = {lb_to_id[lb]: lb for lb in lb_to_id.keys()}

# %%
for i in range(10):
    print(list(wd_ary)[i], list(wd_cnt)[i])
    #print(list(wd_set.keys())[i], list(wd_set.values())[i])
# Out:
# EOS 8175
# の 3017
# ます 2793
# です 2676
# か 2369
# て 2349
# は 2103
# と 2097
# が 2037
# 、 1963

# %%
KIND = len(list(lb_to_id.keys()))
CUT_OFF = 2

print("words kinds:",
      len(wd_cnt), "words>=" + str(CUT_OFF) + ":", np.sum(wd_cnt >= CUT_OFF))
print("all words num:", np.sum(wd_cnt))
print("all words num:", np.sum(wd_cnt[wd_cnt >= CUT_OFF]))

other_id = np.sum(wd_cnt >= CUT_OFF)
wd_to_id.update({wd: other_id for wd in wd_ary[wd_cnt < CUT_OFF]})
print(other_id)
id_to_wd[other_id] = '[X]'

print(max(wd_to_id.values()))

with open('data/New_id_to_wd.pickle', mode='wb') as f:
    pickle.dump(id_to_wd, f)
with open('data/New_wd_to_id.pickle', mode='wb') as f:
    pickle.dump(wd_to_id, f)
with open('data/New_wd_set.pickle', mode='wb') as f:
    pickle.dump(wd_set, f)
with open('data/New_id_to_lb.pickle', mode='wb') as f:
    pickle.dump(id_to_lb, f)
pd.DataFrame(
    np.array(list(id_to_lb.items())).T, index=["ラベルid", "ラベルname"])
# Out:
# words kinds: 2597 words>=2: 2590
# all words num: 97929
# all words num: 97922
# 2590
# 2590
#            0
# ラベルid      0
# ラベルname  NAN

# %%
of = open("data/New_edu_data.txt", "w")
for i, (sen, lb) in enumerate(zip(np.array(new_doc), new_data[:, label])):
    sen_str = "".join([str(wd_to_id[wd]) + " " for wd in sen])
    print_str = str(lb_to_id[lb]) + " " + str(lb_to_id[lb]) + " " + sen_str
    print(print_str, file=of)
of.close()

of = open("data/New_edu_data_pre.txt", "w")
for i, sen in enumerate(np.array(new_doc_pre)):
    sen_str = "".join([str(wd_to_id[wd]) + " " for wd in sen])
    print(sen_str, file=of)
of.close()

print(max([len(sen) for sen in new_doc]))

print(KIND)
# Out:
# 151
# 1
