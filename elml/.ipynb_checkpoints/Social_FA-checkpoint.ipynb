# %%
import numpy as np
import math
import pickle
from openpyxl import Workbook
from openpyxl import load_workbook
import mojimoji
import numpy as np
import glob
import re
import MeCab
import types
import pandas as pd
from collections import Counter
# %matplotlib inline

mc = MeCab.Tagger("-Ochasen")

# %%
dirpath = "data/excel/"

filename = "A_W_171116.xlsx"
A_W_171116_excel = pd.ExcelFile(dirpath + filename)
sheet_name = A_W_171116_excel.sheet_names[0]
A_W_171116_df = A_W_171116_excel.parse(sheet_name)

filename = "A_W_171128.xlsx"
A_W_171128_excel = pd.ExcelFile(dirpath + filename)
sheet_name = A_W_171128_excel.sheet_names[0]
A_W_171128_df = A_W_171128_excel.parse(sheet_name)

filename = "171116.xlsx"
S_H_171116_excel = pd.ExcelFile(dirpath + filename)
sheet_name = S_H_171116_excel.sheet_names[0]
S_H_171116_df = S_H_171116_excel.parse(sheet_name)

filename = "2015斉藤.xlsx"
S_2015_excel = pd.ExcelFile(dirpath + filename)
sheet_name = S_2015_excel.sheet_names[0]
S_2015_df = S_2015_excel.parse(sheet_name)

# %% [markdown]
# ## 必要なデータ
# - id
#     - A_W_YYMMDDのNo.(0列目)
#     - SH_171116のid(0列目)
#     - 斉藤2015の発言番号(0列目)
# - reply
#     - A_W_YYMMDDの返信元(1列目)
#     - SH_171116のreply(3列目)
#     - 斉藤2015の返信元(1列目)
# - group
#     - A_W_YYMMDDのgid(6列目)
#     - SH_171116のgid(5列目)
#     - 斉藤2015のグループ番号(6列目)
# - who
#     - A_W_YYMMDDのニックネーム(8列目)
#     - SH_171116のcname(6列目)
#     - 斉藤2015のニックネーム(8列目)
# - body
#     - A_W_YYMMDDの発言内容(11列目)
#     - SH_171116のbody(8列目)
#     - 斉藤2015の発言内容(11列目)
# - epistemic_a
#     - A_W_YYMMDDのEpistemic(A)(12列目)
#     - Epistemic(H)(9列目)
# - epistemic_b
#     - A_W_YYMMDDのWatanabe(13列目)
#     - Epistemic(S)(10列目)
# - social_table_a
#     - A_W_YYMMDDのSocial(A)(27列目)
#     - SH_171116のSocial(H)(21列目)
# - social_table_b
#     - A_W_YYMMDDのWatanabe.3(28列目)
#     - SH_171116のSocial(S)(22列目)
#
#
# ## 各dfで必要な列
# - A_W_YYMMDD[0, 1, 6, 8, 11, 12, 13, 27, 28]
# - SH_171116[0, 3, 5, 6, 8, 9, 10, 21, 22]
# - 斉藤2015[0, 1, 6, 8, 11]

# %%
A_W_YYMMDD_use = [0, 1, 6, 8, 11, 12, 13, 27, 28]
S_H_171116_use = [0, 3, 5, 6, 8, 9, 10, 21, 22]
S_2015_use = [0, 1, 6, 8, 11]

# %%
# A_W_YYMMDDの列名の統合
A_W_171116_df.columns = A_W_171128_df.columns

delete_columns_list = []
for i, column in enumerate(A_W_171116_df):
    if not i in A_W_YYMMDD_use:
        delete_columns_list.append(column)
        
A_W_171116_df = A_W_171116_df.drop(delete_columns_list, axis=1)
A_W_171128_df = A_W_171128_df.drop(delete_columns_list, axis=1)

delete_columns_list = []
for i, column in enumerate(S_H_171116_df):
    if not i in S_H_171116_use:
        delete_columns_list.append(column)
S_H_171116_df = S_H_171116_df.drop(delete_columns_list, axis=1)

delete_columns_list = []
for i, column in enumerate(S_2015_df):
    if not i in S_2015_use:
        delete_columns_list.append(column)
S_2015_df = S_2015_df.drop(delete_columns_list, axis=1)

# %%
print(not False in S_H_171116_df['id'].values == S_2015_df['発言番号'].values)
print(not False in S_H_171116_df['cname'].values == S_2015_df['ニックネーム'].values)
print(not False in S_H_171116_df['body'].values == S_2015_df['発言内容'].values)
# Out:
# True
# True
# True

# %%
S_H_171116_df["reply"] = S_2015_df['返信元']
S_H_171116_df["gid"] = S_2015_df['グループ番号']
concat_border = 299
A_W_171116_df = A_W_171116_df[0:concat_border]
A_W_171128_df = A_W_171128_df[concat_border:]
A_W_df = pd.concat([A_W_171116_df, A_W_171128_df])

# %%
# 要素含まれるNanの数を確認
A_W_df.isnull().sum()
# Out:
# No.                3
# 返信元                3
# gid                3
# ニックネーム             3
# 発言内容               3
# Epistemic(A)       3
# Watanabe           3
# Social(A)       2881
# Watanabe.3      2746
# dtype: int64

# %% [markdown]
# # 重要！！

# %%
# A_W_dfの人間が付けたラベル列のNanをBlankに変換
A_W_df = A_W_df.fillna('Blank')
# 要素にNanが含まれる列を再確認
A_W_df.isnull().any()
# Out:
# No.             False
# 返信元             False
# gid             False
# ニックネーム          False
# 発言内容            False
# Epistemic(A)    False
# Watanabe        False
# Social(A)       False
# Watanabe.3      False
# dtype: bool

# %%
# 要素に含まれるNanの数を確認
S_H_171116_df.isnull().sum()
# Out:
# id                 0
# reply              0
# gid                0
# cname              0
# body               0
# Epistemic(H)       1
# Epistemic(S)       4
# Social(H)       2832
# Social(S)       2823
# dtype: int64

# %% [markdown]
# # 重要！！

# %%
# S_H_171116_dfの人間が付けたラベル列のNanを取り除く
S_H_171116_df = S_H_171116_df.fillna('Blank')
# 要素にNanが含まれる列を再確認
S_H_171116_df.isnull().any()
# Out:
# id              False
# reply           False
# gid             False
# cname           False
# body            False
# Epistemic(H)    False
# Epistemic(S)    False
# Social(H)       False
# Social(S)       False
# dtype: bool

# %% [markdown]
# # 重要！！

# %%
A_W_df = A_W_df.drop_duplicates(subset=['ニックネーム', '発言内容'])
S_H_171116_df = S_H_171116_df.drop_duplicates(subset=['cname', 'body'])

# %%
counter = Counter(A_W_df['Watanabe.3'])
print(counter)
A_W_df = A_W_df[A_W_df['Watanabe.3'] != 2723]
counter = Counter(A_W_df['Watanabe.3'])
print(counter)
# Out:
# Counter({'Blank': 2475, 'Externalization': 1192, 'Quick consensus building': 526, 'Elicitation': 194, 'Integrarion-oriented consensus building': 151, 'Conflict-oriented consensus building': 41, 'Summary': 23, 2723: 2})
# Counter({'Blank': 2475, 'Externalization': 1192, 'Quick consensus building': 526, 'Elicitation': 194, 'Integrarion-oriented consensus building': 151, 'Conflict-oriented consensus building': 41, 'Summary': 23})

# %% [markdown]
# # 重要！！

# %%
# 表記ゆれの修正と確認
A_W_df['Social(A)'] = A_W_df['Social(A)'].str.lower()
counter = Counter(A_W_df['Social(A)'])
print(counter)
A_W_df['Watanabe.3'] = A_W_df['Watanabe.3'].str.lower()
counter = Counter(A_W_df['Watanabe.3'])
print(counter)
# Out:
# Counter({'blank': 2645, 'externalization': 856, 'quick consensus building': 563, 'elicitation': 231, 'integrarion-oriented consensus building': 111, 'integration-oriented consensus building': 99, 'summary': 56, 'conflict-oriented consensus building': 41})
# Counter({'blank': 2475, 'externalization': 1192, 'quick consensus building': 526, 'elicitation': 194, 'integrarion-oriented consensus building': 151, 'conflict-oriented consensus building': 41, 'summary': 23})

# %% [markdown]
# # 重要！！

# %%
# 表記ゆれの確認
S_H_171116_df['Social(S)'] = S_H_171116_df['Social(S)'].str.lower()
counter = Counter(S_H_171116_df['Social(S)'])
print(counter)
S_H_171116_df['Social(H)'] = S_H_171116_df['Social(H)'].str.lower()
counter = Counter(S_H_171116_df['Social(H)'])
print(counter)
# Out:
# Counter({'blank': 2557, 'externalization': 834, 'quick consensus building': 690, 'elicitation': 268, 'integrarion-oriented consensus building': 233, 'conflict-oriented consensus building': 129, 'summary': 28})
# Counter({'blank': 2601, 'externalization': 992, 'quick consensus building': 632, 'elicitation': 260, 'integrarion-oriented consensus building': 106, 'conflict-oriented consensus building': 80, 'integration-oriented consensus building': 42, 'summary': 26})

# %%
correct_label = 'integration-oriented consensus building'
incorrect_label = 'integrarion-oriented consensus building'

A_W_df['Social(A)'] = A_W_df['Social(A)'].where(A_W_df['Social(A)'] != incorrect_label, correct_label)
counter = Counter(A_W_df['Social(A)'])
print(counter)
A_W_df['Watanabe.3'] = A_W_df['Watanabe.3'].where(A_W_df['Watanabe.3'] != incorrect_label, correct_label)
counter = Counter(A_W_df['Watanabe.3'])
print(counter)

S_H_171116_df['Social(S)'] = S_H_171116_df['Social(S)'].where(S_H_171116_df['Social(S)'] != incorrect_label, correct_label)
counter = Counter(S_H_171116_df['Social(S)'])
print(counter)
S_H_171116_df['Social(H)'] = S_H_171116_df['Social(H)'].where(S_H_171116_df['Social(H)'] != incorrect_label, correct_label)
counter = Counter(S_H_171116_df['Social(H)'])
print(counter)
# Out:
# Counter({'blank': 2645, 'externalization': 856, 'quick consensus building': 563, 'elicitation': 231, 'integration-oriented consensus building': 210, 'summary': 56, 'conflict-oriented consensus building': 41})
# Counter({'blank': 2475, 'externalization': 1192, 'quick consensus building': 526, 'elicitation': 194, 'integration-oriented consensus building': 151, 'conflict-oriented consensus building': 41, 'summary': 23})
# Counter({'blank': 2557, 'externalization': 834, 'quick consensus building': 690, 'elicitation': 268, 'integration-oriented consensus building': 233, 'conflict-oriented consensus building': 129, 'summary': 28})
# Counter({'blank': 2601, 'externalization': 992, 'quick consensus building': 632, 'elicitation': 260, 'integration-oriented consensus building': 148, 'conflict-oriented consensus building': 80, 'summary': 26})

# %%
# 表記ゆれの修正と確認
A_W_df['Epistemic(A)'] = A_W_df['Epistemic(A)'].str.lower()
counter = Counter(A_W_df['Epistemic(A)'])
print(counter)
A_W_df['Watanabe'] = A_W_df['Watanabe'].str.lower()
counter = Counter(A_W_df['Watanabe'])
print(counter)
# Out:
# Counter({'off task': 2392, 'on task': 2090, 'no sense': 119, 'blank': 1})
# Counter({'off task': 2444, 'on task': 2146, 'no sense': 11, 'blank': 1})

# %%
# 表記ゆれの確認
S_H_171116_df['Epistemic(S)'] = S_H_171116_df['Epistemic(S)'].str.lower()
counter = Counter(S_H_171116_df['Epistemic(S)'])
print(counter)
S_H_171116_df['Epistemic(H)'] = S_H_171116_df['Epistemic(H)'].str.lower()
counter = Counter(S_H_171116_df['Epistemic(H)'])
print(counter)
# Out:
# Counter({'off task': 2546, 'on task': 2179, 'no sense': 10, 'blank': 4})
# Counter({'off task': 2560, 'on task': 2165, 'no sense': 13, 'blank': 1})

# %%
A_W_df = A_W_df[A_W_df['Epistemic(A)'] != 'no sense']
A_W_df = A_W_df[A_W_df['Watanabe'] != 'no sense']
A_W_df = A_W_df[A_W_df['Epistemic(A)'] != 'blank']
A_W_df = A_W_df[A_W_df['Watanabe'] != 'blank']
print(Counter(A_W_df['Epistemic(A)']))
print(Counter(A_W_df['Watanabe']))
# Out:
# Counter({'off task': 2390, 'on task': 2089})
# Counter({'off task': 2337, 'on task': 2142})

# %%
S_H_171116_df = S_H_171116_df[S_H_171116_df['Epistemic(H)'] != 'no sense']
S_H_171116_df = S_H_171116_df[S_H_171116_df['Epistemic(S)'] != 'no sense']
S_H_171116_df = S_H_171116_df[S_H_171116_df['Epistemic(H)'] != 'blank']
S_H_171116_df = S_H_171116_df[S_H_171116_df['Epistemic(S)'] != 'blank']
print(Counter(S_H_171116_df['Epistemic(H)']))
print(Counter(S_H_171116_df['Epistemic(S)']))
# Out:
# Counter({'off task': 2558, 'on task': 2158})
# Counter({'off task': 2538, 'on task': 2178})

# %% [markdown]
# # 重要！！

# %%
A_W_match_df = A_W_df[A_W_df['Social(A)'] == A_W_df['Watanabe.3']].reset_index(drop=True)
A_W_match_df.head()
# Out:
#    No. 返信元 gid ニックネーム                          発言内容 Epistemic(A)  Watanabe  \
# 0    1  \N   1   まこぴす                   よろしくお願いします！     off task  off task
# 1   31  \N   1      哲                    よろしくお願いします     off task  off task
# 2   70  \N   1     仙波  名前なのが恥ずかしいです…\n\nよろしくお願いします！     off task  off task
# 3  119  \N   1   まこぴす                早速課題やっちゃいましょう！     off task  off task
# 4  302  \N   1      哲                          同意です      on task   on task
#
#                   Social(A)                Watanabe.3
# 0                     blank                     blank
# 1                     blank                     blank
# 2                     blank                     blank
# 3                     blank                     blank
# 4  quick consensus building  quick consensus building

# %% [markdown]
# # 重要！！

# %%
S_H_match_df = S_H_171116_df[S_H_171116_df['Social(H)'] == S_H_171116_df['Social(S)']].reset_index(drop=True)
S_H_match_df.head()
# Out:
#      id reply  gid   cname                body Epistemic(H) Epistemic(S)  \
# 0  1593    \N    1  世界のわたべ         よろしくお願いします。     off task     off task
# 1  1598    \N    1    ざきさん              よろしくです     off task     off task
# 2  1606    \N    1       あ              よろしくです     off task     off task
# 3  1659    \N    1    ざきさん  みなさんファイルをアップしましたか？     off task     off task
# 4  1683    \N    1       あ           今アップしました！     off task     off task
#
#   Social(H) Social(S)
# 0     blank     blank
# 1     blank     blank
# 2     blank     blank
# 3     blank     blank
# 4     blank     blank

# %%
A_W_match_df.isnull().sum()
# Out:
# No.             0
# 返信元             0
# gid             0
# ニックネーム          0
# 発言内容            0
# Epistemic(A)    0
# Watanabe        0
# Social(A)       0
# Watanabe.3      0
# dtype: int64

# %%
S_H_match_df.isnull().sum()
# Out:
# id              0
# reply           0
# gid             0
# cname           0
# body            0
# Epistemic(H)    0
# Epistemic(S)    0
# Social(H)       0
# Social(S)       0
# dtype: int64

# %% [markdown]
# # 重要！！

# %%
header = ['id', 'reply', 'group_id', 'cname', 'body', 'Epistemic_A', 'Epistemic_B', 'Social_A', 'Social_B']
A_W_df.columns = header
S_H_171116_df.columns = header
A_W_match_df.columns = header
S_H_match_df.columns = header
All_df = pd.concat([A_W_df, S_H_171116_df], ignore_index=True)
match_df = pd.concat([A_W_match_df, S_H_match_df], ignore_index=True)
print(match_df.shape[0]/All_df.shape[0] *100)

print(A_W_df.shape)
print(S_H_171116_df.shape)
print(All_df.shape)
print(match_df.shape)
# Out:
# 78.11854268624252
# (4479, 9)
# (4716, 9)
# (9195, 9)
# (7183, 9)

# %%
# データの形式の定義
data_format = ['id', 'reply', 'group_id', 'cname', 'body', 'epistemic', 'label']
# 名前からデータのindexに変換する辞書
data_index = {column : i for i, column in enumerate(data_format)}
print(data_index)

id = 0
reply = 1
group_id = 2
cname = 3
body = 4
epistemic = 5
label = 6

df_index = {column: i for i, column in enumerate(All_df)}
print(df_index)
# Out:
# {'reply': 1, 'group_id': 2, 'cname': 3, 'label': 6, 'body': 4, 'id': 0, 'epistemic': 5}
# {'reply': 1, 'group_id': 2, 'cname': 3, 'Epistemic_A': 5, 'Social_A': 7, 'Epistemic_B': 6, 'body': 4, 'id': 0, 'Social_B': 8}

# %% [markdown]
# # 重要！！

# %%
df_use = [0, 1, 2, 3, 4]

# All_df_index['ラベル名']を変更して取り出すラベルを分ける
# epistemic_position = df_index['Epistemic_A']
# epistemic_position = df_index['Epistemic_B']
epistemic_position = df_index['Epistemic_B']
df_use.append(epistemic_position)

# label_position = df_index['Social_A']
# label_position = df_index['Social_B']
label_position = df_index['Social_B']
df_use.append(label_position)

print(df_use)

delete_columns_list = []
# for i, column in enumerate(All_df):
for i, column in enumerate(match_df):
    if not i in df_use:
        delete_columns_list.append(column)
# input_df = All_df.drop(delete_columns_list, axis=1)
input_df = match_df.drop(delete_columns_list, axis=1)
# input_df = A_W_consulted_df.drop(delete_columns_list, axis=1)
input_df.columns = data_format
# Out:
# [0, 1, 2, 3, 4, 6, 8]

# %%
input_df
# Out:
#         id reply group_id    cname  \
# 0        1    \N        1     まこぴす
# 1       31    \N        1        哲
# 2       70    \N        1       仙波
# 3      119    \N        1     まこぴす
# 4      302    \N        1        哲
# 5      309    \N        1       仙波
# 6      385    \N        1     まこぴす
# 7      500    \N        1       仙波
# 8      528    \N        1       仙波
# 9      693    \N        1     まこぴす
# 10     813    \N        1     まこぴす
# 11     830   746        1        哲
# 12     831    \N        1       仙波
# 13     899    \N        1     まこぴす
# 14     916    \N        1       仙波
# 15     934   899        1        哲
# 16     964    \N        1     まこぴす
# 17     990    \N        1       仙波
# 18    1017    \N        1       \N
# 19    1031    \N        1     まこぴす
# 20    1048    \N        1       仙波
# 21    1066    \N        1        哲
# 22    1101    \N        1       仙波
# 23    1107    \N        1     まこぴす
# 24      27    \N        2      マニン
# 25      90    \N        2  Houdini
# 26      91    \N        2     あひるぅ
# 27     174    \N        2     あひるぅ
# 28     184   174        2      マニン
# 29     199   184        2     あひるぅ
# ...    ...   ...      ...      ...
# 7153  6189  6183    10001      みずき
# 7154  6204  6189    10001      まささ
# 7155  6224    \N    10001     オノヅカ
# 7156  6237  6224    10001      みずき
# 7157  6241  6224    10001      まささ
# 7158  6243    \N    10001     オノヅカ
# 7159  6254    \N    10001     オノヅカ
# 7160  6257  6254    10001      まささ
# 7161  6264  6254    10001      みずき
# 7162  6266    \N    10001     オノヅカ
# 7163  6278  6266    10001      まささ
# 7164  6280  6266    10001      みずき
# 7165  6288    \N    10001     オノヅカ
# 7166  6326    \N    10001     オノヅカ
# 7167  6347    \N    10001      みずき
# 7168  6363    \N    10001      まささ
# 7169  6388    \N    10001     オノヅカ
# 7170  6404  6388    10001      みずき
# 7171  6410  6404    10001     オノヅカ
# 7172  6415    \N    10001      まささ
# 7173  6419  6404    10001      まささ
# 7174  6435  6415    10001      みずき
# 7175  6449    \N    10001     オノヅカ
# 7176  6451  6443    10001      みずき
# 7177  6459    \N    10001      みずき
# 7178  6463  6459    10001      まささ
# 7179  6467  6459    10001     オノヅカ
# 7180  6477    \N    10001     オノヅカ
# 7181  6491  6477    10001      まささ
# 7182  6521    \N    10001     オノヅカ
#
#                                                    body epistemic  \
# 0                                           よろしくお願いします！  off task
# 1                                            よろしくお願いします  off task
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！  off task
# 3                                        早速課題やっちゃいましょう！  off task
# 4                                                  同意です   on task
# 5     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...   on task
# 6     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...   on task
# 7                                              ほぼほぼ同意です   on task
# 8                                     他に何か考えてることなどありますか   on task
# 9                                           他に意見ありますかー？   on task
# 10                             １度共有テキスト全部消して現在の回答案書きます！  off task
# 11                       > 哲さんどうですか？\n\n自分もみなさんの意見に同意です   on task
# 12                                                 了解です   on task
# 13                      こちらの回答案でよければ課題回答しちゃいますけど大丈夫ですか？  off task
# 14                                              自分は平気です  off task
# 15                                          よろしくお願いします！  off task
# 16                                                完了です！  off task
# 17                                              お疲れ様です！  off task
# 18                                           １番乗りおめでとう！  off task
# 19                                        ありがとうございます(笑)  off task
# 20                                                  でた！  off task
# 21                       お役に立てず申し訳ございません\n\nありがとうごいました！  off task
# 22                        お疲れ様でした！\n\nまた何かあればその時はよろしくです  off task
# 23                                       いえいえ！お疲れさまでした！  off task
# 24                                                よろしくー  off task
# 25                                                よろしゅー  off task
# 26                                           おはようございました  off task
# 27                                        ていうか帰りませんか？？？  off task
# 28                        > ていうか帰りませんか？？？\n\nどうぞお帰りください  off task
# 29    > &gt; ていうか帰りませんか？？？\n\n\n\n> どうぞお帰りください\n\n\n...  off task
# ...                                                 ...       ...
# 7153  > 共有テキストに書いてある感じで提出しちゃいますか？\nいや、変更があればどんどん訂正して...  off task
# 7154  > &gt; 共有テキストに書いてある感じで提出しちゃいますか？\n\n> いや、変更があれ...  off task
# 7155                          共有テキストの下半分のやつで出しちゃおうと思ってる  off task
# 7156                 > 共有テキストの下半分のやつで出しちゃおうと思ってる\n了解です！  off task
# 7157               > 共有テキストの下半分のやつで出しちゃおうと思ってる\nわかりました！  off task
# 7158                                       じゃあ提出しておきますね  off task
# 7159                                             提出しました  off task
# 7160                             > 提出しました\nありがとうございます！！  off task
# 7161                              > 提出しました\nありがとうございます！  off task
# 7162                                   共有テキスト一回消しちゃいます？  off task
# 7163                        > 共有テキスト一回消しちゃいます？\nそうしましょう  off task
# 7164           > 共有テキスト一回消しちゃいます？\nそうしましょう！で、課題2やりましょう！  off task
# 7165             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ   on task
# 7166                        SCORMの次世代版でビッグデータにも対応してるらしい   on task
# 7167  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...   on task
# 7168                               スマホアプリやタブレットでの利用もできる   on task
# 7169                                    今出てきた意見全部繋げちゃう？  off task
# 7170                    > 今出てきた意見全部繋げちゃう？\n今つなげようとしてます！  off task
# 7171   > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\nお願いします  off task
# 7172  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...   on task
# 7173  > &gt; 今出てきた意見全部繋げちゃう？\n\n> 今つなげようとしてます！\n\nあり...  off task
# 7174  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...   on task
# 7175                                           提出お願いします  off task
# 7176  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...  off task
# 7177                                         課題2提出完了です！  off task
# 7178                          > 課題2提出完了です！\nありがとうございます！  off task
# 7179                           > 課題2提出完了です！\nありがとうございます  off task
# 7180                                           課題3やりますか  off task
# 7181              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね  off task
# 7182                            「何を」の部分の選択肢が後1つくらい欲しいかな  off task
#
#                          label
# 0                        blank
# 1                        blank
# 2                        blank
# 3                        blank
# 4     quick consensus building
# 5              externalization
# 6              externalization
# 7     quick consensus building
# 8                  elicitation
# 9                  elicitation
# 10                       blank
# 11    quick consensus building
# 12    quick consensus building
# 13                       blank
# 14                       blank
# 15                       blank
# 16                       blank
# 17                       blank
# 18                       blank
# 19                       blank
# 20                       blank
# 21                       blank
# 22                       blank
# 23                       blank
# 24                       blank
# 25                       blank
# 26                       blank
# 27                       blank
# 28                       blank
# 29                       blank
# ...                        ...
# 7153                     blank
# 7154                     blank
# 7155                     blank
# 7156                     blank
# 7157                     blank
# 7158                     blank
# 7159                     blank
# 7160                     blank
# 7161                     blank
# 7162                     blank
# 7163                     blank
# 7164                     blank
# 7165           externalization
# 7166           externalization
# 7167           externalization
# 7168           externalization
# 7169                     blank
# 7170                     blank
# 7171                     blank
# 7172           externalization
# 7173                     blank
# 7174  quick consensus building
# 7175                     blank
# 7176                     blank
# 7177                     blank
# 7178                     blank
# 7179                     blank
# 7180                     blank
# 7181                     blank
# 7182                     blank
#
# [7183 rows x 7 columns]

# %%
input_df = input_df[input_df['epistemic'] == 'on task'].reset_index(drop=True)
input_df
# Out:
#         id reply group_id     cname  \
# 0      302    \N        1         哲
# 1      309    \N        1        仙波
# 2      385    \N        1      まこぴす
# 3      500    \N        1        仙波
# 4      528    \N        1        仙波
# 5      693    \N        1      まこぴす
# 6      830   746        1         哲
# 7      831    \N        1        仙波
# 8      268    \N        2      あひるぅ
# 9      396   268        2       マニン
# 10     524    \N        2       マニン
# 11     534    \N        2   Houdini
# 12     615    \N        2       マニン
# 13     866    \N        2       マニン
# 14     906    \N        2      あひるぅ
# 15     911    \N        2   Houdini
# 16    1087   906        2       マニン
# 17     676    \N        3     kouta
# 18     694    \N        3       いつき
# 19     752    \N        3     match
# 20     833    \N        3     match
# 21    1351    \N        3       いつき
# 22    1360    \N        3     kouta
# 23     232   201        4    世界のわたべ
# 24     265    \N        4        TJ
# 25     296   265        4    世界のわたべ
# 26     299    \N        4     omori
# 27     400    \N        4        TJ
# 28     430    \N        4     omori
# 29     460   400        4    世界のわたべ
# ...    ...   ...      ...       ...
# 2589  6057    \N        1      ショウゴ
# 2590  6147    \N        1      ざっきー
# 2591  6263    \N        1      ショウゴ
# 2592  6303    \N        1      ざっきー
# 2593  6321    \N        1      ショウゴ
# 2594  6323    \N        1      ざっきー
# 2595  6340    \N        1       イヌイ
# 2596  6374    \N        1       イヌイ
# 2597  6380    \N        1      ショウゴ
# 2598  6381    \N        1      ざっきー
# 2599  6431    \N        1      ショウゴ
# 2600  6444    \N        1       イヌイ
# 2601  6118    \N        2  H.Yamato
# 2602  6220    \N        2  H.Yamato
# 2603  6236    \N        2  H.Yamato
# 2604  6253  6220        2        ノラ
# 2605  6272    \N        2       まろん
# 2606  6284    \N        2  H.Yamato
# 2607  6293  6284        2        ノラ
# 2608  6081    \N    10001      オノヅカ
# 2609  6084    \N    10001       まささ
# 2610  6121    \N    10001       みずき
# 2611  6131  6081    10001       みずき
# 2612  6142  6117    10001       まささ
# 2613  6288    \N    10001      オノヅカ
# 2614  6326    \N    10001      オノヅカ
# 2615  6347    \N    10001       みずき
# 2616  6363    \N    10001       まささ
# 2617  6415    \N    10001       まささ
# 2618  6435  6415    10001       みずき
#
#                                                    body epistemic  \
# 0                                                  同意です   on task
# 1     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...   on task
# 2     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...   on task
# 3                                              ほぼほぼ同意です   on task
# 4                                     他に何か考えてることなどありますか   on task
# 5                                           他に意見ありますかー？   on task
# 6                        > 哲さんどうですか？\n\n自分もみなさんの意見に同意です   on task
# 7                                                  了解です   on task
# 8              課題のアップロードはともかくチャット機能は使いづらいと思うのですがいかがですか？   on task
# 9     > 課題のアップロードはともかくチャット機能は使いづらいと思うのですがいかがですか？\n\n...   on task
# 10                       ファイルアップロードはドラック＆ドロップができるのはいいかな   on task
# 11              メモ帳打ってからじゃないと安心出来ないのはNG\n\nエラー警告も出なかったわ   on task
# 12                   課題の一覧とか欲しいですよね\n\nカレンダー化してくれるとまだいい   on task
# 13                              チャットの話題できてきてたけど、どうまとめる？   on task
# 14                                    使いづらい点って簡単にわかります？   on task
# 15    アンケートや課題提出は去年と比べると簡単になって良かったですね\n\nチャット機能はそもそも...   on task
# 16                  > 使いづらい点って簡単にわかります？\n\nあなたはどう思いますか？   on task
# 17                                        簡単で使いやすいと思います   on task
# 18                              自分は前のシステムよりは使いやすいと思います。   on task
# 19    私は、提出物などが大変出し易くなってかなり便利だと思います。また、出し忘れているものや期限が...   on task
# 20                  意見をまとめなければいけないので、なるべく具体的な回答をお願いします。   on task
# 21    課題を出すのも簡単ですし、授業ページも見つけやすいように、週の時間割が表示されているのが良い...   on task
# 22    誰もが簡単に捜査できるとは限らないが、オフィスソフトを一通り使いこなせる、画面の指示に従って...   on task
# 23                                         使いやすいです。\n\n   on task
# 24                                    assitって不便だったんですか？   on task
# 25                                         課題提出とかが不便でした   on task
# 26                                  いちいちパスワード入れるのが大変なので   on task
# 27                                   assitって自宅からつなげました？   on task
# 28                                       つなげられたような気がします   on task
# 29                                   つなげるけど設定が面倒でした\n\n   on task
# ...                                                 ...       ...
# 2589                              目的入ってる方がいいですね！\nそっちで！   on task
# 2590                     これにeラーニングにおける位置づけ\nってのを添える感じかな   on task
# 2591  とてもいいと思う！\n個人的にはLRSの記述が一行くらい欲しいかな\nLMSとは違いLRSを...   on task
# 2592  LRS使ったからSCORMより良くなったってのが分かるし、そのほうが綺麗な回答だねー\nいい...   on task
# 2593                                        （正式名称…）のとこ？   on task
# 2594             あー正式名称要らないよって事ね。\n問題はTinCanって言ってるし、確かに   on task
# 2595                                     大丈夫です\nありがとう！！   on task
# 2596  あ、ゴメン\n話跳ぶけど１つ目の課題も\nSCORMとは、eラーニングにおける共通化のための...   on task
# 2597                                   大丈夫ですよ～\nお願いします！   on task
# 2598                そうだね。あっちだけ書いてあってもおかしいし\n消してもらえると助かる   on task
# 2599                   そんなに削る必要ある？\n文字数制限無いからいいんじゃないかな？   on task
# 2600                         そうだね\nまとまってる弄る必要もないね\nスマン汗   on task
# 2601  「SCORMってブラウザで扱うもの」みたいな記述があっても良いかもです。\n\nTin Ca...   on task
# 2602  SCROMに比べて運用も簡単みたい。あと何よりもブラウザ以外のタブレットなどでも使えるってい...   on task
# 2603                                         これも分かりやすい。   on task
# 2604  > SCROMに比べて運用も簡単みたい。あと何よりもブラウザ以外のタブレットなどでも使えるっ...   on task
# 2605                                     自分はこんな感じでいいと思う   on task
# 2606  問題に書いてある、eラーニングにおける位置づけについては、\n\n「eラーニングに欠かせない...   on task
# 2607  > 問題に書いてある、eラーニングにおける位置づけについては、\n\n> \n\n> 「eラ...   on task
# 2608  プラットフォーム上で教材のデータを共有するやりとりとそのインターフェースの規定の標準規格\n...   on task
# 2609  異なるLMS間で教材の互換性がなかったものをSOORMによって標準化対応させることで他社のL...   on task
# 2610              さまざまなLMSに同一の学習コンテンツを動作させるための国際標準規格です。   on task
# 2611  > プラットフォーム上で教材のデータを共有するやりとりとそのインターフェースの規定の標準規格...   on task
# 2612  > これを少し削った感じでいいと思います\n\n> \n\n> &gt; 異なるLMS間で教...   on task
# 2613             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ   on task
# 2614                        SCORMの次世代版でビッグデータにも対応してるらしい   on task
# 2615  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...   on task
# 2616                               スマホアプリやタブレットでの利用もできる   on task
# 2617  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...   on task
# 2618  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...   on task
#
#                                         label
# 0                    quick consensus building
# 1                             externalization
# 2                             externalization
# 3                    quick consensus building
# 4                                 elicitation
# 5                                 elicitation
# 6                    quick consensus building
# 7                    quick consensus building
# 8                                 elicitation
# 9                             externalization
# 10                            externalization
# 11                            externalization
# 12                            externalization
# 13                                elicitation
# 14                                elicitation
# 15                            externalization
# 16                                elicitation
# 17                            externalization
# 18                            externalization
# 19                            externalization
# 20                                      blank
# 21                            externalization
# 22                            externalization
# 23                            externalization
# 24                                elicitation
# 25                            externalization
# 26                            externalization
# 27                                elicitation
# 28                            externalization
# 29                            externalization
# ...                                       ...
# 2589                 quick consensus building
# 2590                          externalization
# 2591  integration-oriented consensus building
# 2592                 quick consensus building
# 2593                              elicitation
# 2594                 quick consensus building
# 2595                 quick consensus building
# 2596                              elicitation
# 2597                 quick consensus building
# 2598                 quick consensus building
# 2599     conflict-oriented consensus building
# 2600                 quick consensus building
# 2601                          externalization
# 2602                          externalization
# 2603                          externalization
# 2604                 quick consensus building
# 2605                 quick consensus building
# 2606                          externalization
# 2607                 quick consensus building
# 2608                          externalization
# 2609                          externalization
# 2610                          externalization
# 2611                 quick consensus building
# 2612                 quick consensus building
# 2613                          externalization
# 2614                          externalization
# 2615                          externalization
# 2616                          externalization
# 2617                          externalization
# 2618                 quick consensus building
#
# [2619 rows x 7 columns]

# %%
counter = Counter(input_df['label'])
print(counter)
# Out:
# Counter({'externalization': 1285, 'quick consensus building': 859, 'elicitation': 278, 'integration-oriented consensus building': 102, 'conflict-oriented consensus building': 63, 'summary': 20, 'blank': 12})

# %%
counter = Counter(input_df['label'])
ranked_data = counter.most_common()

ranked_data
# Out:
# [('externalization', 1285),
#  ('quick consensus building', 859),
#  ('elicitation', 278),
#  ('integration-oriented consensus building', 102),
#  ('conflict-oriented consensus building', 63),
#  ('summary', 20),
#  ('blank', 12)]

# %%
input_data = input_df.values

# %%
def preprocess(xs, trim_citation=False):
    zs = [""] * len(xs)
    '''全角空白'''
    for i, l in enumerate(xs):
        xs[i] = re.sub('　', ' ', str(l))
    '''多重引用'''
    for i, l in enumerate(xs):
        xs[i] = re.sub('＆ｇｔ；', '＞', l)
    '''引用部分は除外'''
    count_refer = 0
    for i, l in enumerate(xs):
        sen = ""
        have_refer = 1
        for x in l.split('\n'):
            if len(x) == 0:
                continue
            elif x[0].encode('utf-8') == '＞'.encode('utf-8'):
                have_refer = 1
                x = x[1:]
                if len(x) > 0 and x[0].encode('utf-8') != '＞'.encode('utf-8') and \
                        x[0:2].encode('utf-8') != ' ＞'.encode('utf-8') and x != ' ':
                    if trim_citation:
                        zs[i] += x + '\n'
                    else:
                        sen = sen + "＞ " + x + '\n'
                continue
            else:
                sen = sen + x + '\n'
        xs[i] = sen.strip()
        count_refer += have_refer
    '''顔文字'''
    pat = re.compile('（[^ぁ-んァ-ン一-龠]+?）', re.U)
    for i, l in enumerate(xs):
        xs[i] = re.sub(pat, ' KAOMOJI ', l)
    '''日本語及び記号{？！ー〜。、} のみ有効'''
    pat = re.compile('[^＞ Ａ-Ｚａ-ｚ０-９ぁ-んァ-ン一-龠？！ー〜。、\n]+?', re.U)
    for i, l in enumerate(xs):
        xs[i] = re.sub(pat, '', l)
    '''記号繰り返し'''
    pat_1 = re.compile('[ｗ]{1,}', re.U)
    pat_2 = re.compile('[？]{1,}', re.U)
    pat_3 = re.compile('[！]{1,}', re.U)
    pat_4 = re.compile('[～]{1,}', re.U)
    pat_5 = re.compile('[ー]{1,}', re.U)
    pat_6 = re.compile('[。]{1,}', re.U)

    for i, l in enumerate(xs):
        l = re.sub(pat_1, 'ｗ', l)
        l = re.sub(pat_2, '？', l)
        l = re.sub(pat_3, '！', l)
        l = re.sub(pat_4, '～', l)
        l = re.sub(pat_5, 'ー', l)
        l = re.sub(pat_6, '。', l)
        xs[i] = l

    if trim_citation:
        return zs
    else:
        return None

# %%
def make_xs(orig, trim_citation=False, use_seq2seq=False):

    tmp = np.copy(orig)
    xs = tmp[:, body]
    zs = preprocess(xs, trim_citation=(trim_citation or use_seq2seq))

    if use_seq2seq:
        tmp_prev = np.roll(tmp, 1, axis=0)
        tmp_prev[0, 0] = ""
        ts = tmp[:, [1, 2]]
        xs_prev = tmp_prev[:, body]

        for i in range(len(tmp)):
            if tmp[i, group_id] != tmp_prev[i, group_id]:  # group が異なる
                xs_prev[i] = ""
        preprocess(xs_prev, trim_citation=True)

        for i in range(len(xs)):
            replay_to = tmp[i, 2]
            if zs[i] != "":
                xs_prev[i] = zs[i]
            elif replay_to != -1:
                a = xs[:i][tmp[:i, 1] == replay_to]
                if len(a) != 0:
                    xs_prev[i] = a[-1]

        return xs, xs_prev
    else:
        return xs

# %%
def get_doc(xs):
    doc = []
    for ll in xs:
        sen = []
        for l in ll.split('\n'):
            for w in mc.parse(l).split('\n'):
                mx = w.split('\t')
                if len(mx[0]) > 0:
                    sen.append(mx[0])
        doc.append(sen)
    return doc

# %%
xs, xs_pre = make_xs(input_data, trim_citation=True, use_seq2seq=True)
doc = get_doc(xs)
doc_pre = get_doc(xs_pre)
for i in doc[:10]:
    print(" ".join(i))
# Out:
# 同意 です EOS
# 以前 インタラクティブ アート 受講 し て い た の です が 、 その 時 に 課題 が 不具合 で 出せ なく なっ て い た 時期 が あり まし て EOS 本当に もろい です EOS
# 学習 環境 として 必要 最低限 の 機能 は 備え て いる と 思う が 、 操作 性 の 面 で は の 最低限 の 知識 が ある こと が 前提 な ので 誰 も が 利用 できる と は 言え ない 。 また から だ と 見 やすい レイアウト も スマフォ から だ と 見 にくい と 感じ た 。 EOS
# ほぼ ほぼ 同意 です EOS
# 他 に 何 か 考え てる こと など あり ます か EOS
# 他 に 意見 あり ます か ー ？ EOS
# 哲 さん どう です か ？ EOS 自分 も みなさん の 意見 に 同意 です EOS
# 了解 です EOS
# 課題 の アップ ロード は ともかく チャット 機能 は 使い づらい と 思う の です が いかが です か ？ EOS
# 課題 の アップ ロード は ともかく チャット 機能 は 使い づらい と 思う の です が いかが です か ？ EOS チャット について は ログ が 別 ページ で 見 なき ゃいけないのはめんどくさいですね EOS

# %%
wd_set = Counter([x for sen in doc + doc_pre for x in sen])
wd_ary = np.array(list(wd_set.keys()))
wd_cnt = np.array(list(wd_set.values()))
wd_ary = wd_ary[np.argsort(wd_cnt)[::-1]]
wd_cnt.sort()
wd_cnt = wd_cnt[::-1]
wd_to_id = {wd: i for i, wd in enumerate(wd_ary)}
lb_to_id = {lb: i for i, lb in enumerate({x for x in input_data[:, label]})}
id_to_wd = {wd_to_id[wd]: wd for wd in wd_to_id.keys()}
id_to_lb = {lb_to_id[lb]: lb for lb in lb_to_id.keys()}
for i in range(10):
    print(list(wd_ary)[i], list(wd_cnt)[i])
    #print(list(wd_set.keys())[i], list(wd_set.values())[i])
# Out:
# EOS 8800
# の 4787
# が 3203
# は 3140
# と 3074
# に 2979
# か 2787
# です 2780
# 、 2757
# て 2667

# %% [markdown]
# # 重要！！

# %%
KIND = len(list(lb_to_id.keys()))
CUT_OFF = 2

print("words kinds:",
      len(wd_cnt), "words>=" + str(CUT_OFF) + ":", np.sum(wd_cnt >= CUT_OFF))
print("all words num:", np.sum(wd_cnt))
print("all words num:", np.sum(wd_cnt[wd_cnt >= CUT_OFF]))

other_id = np.sum(wd_cnt >= CUT_OFF)
wd_to_id.update({wd: other_id for wd in wd_ary[wd_cnt < CUT_OFF]})
print(other_id)
id_to_wd[other_id] = '[X]'

print(max(wd_to_id.values()))

with open('data/Social_FA_id_to_wd.pickle', mode='wb') as f:
    pickle.dump(id_to_wd, f)
with open('data/Social_FA_wd_to_id.pickle', mode='wb') as f:
    pickle.dump(wd_to_id, f)
with open('data/Social_FA_wd_set.pickle', mode='wb') as f:
    pickle.dump(wd_set, f)
with open('data/Social_FA_id_to_lb.pickle', mode='wb') as f:
    pickle.dump(id_to_lb, f)
pd.DataFrame(
    np.array(list(id_to_lb.items())).T, index=["ラベルid", "ラベルname"])
# Out:
# words kinds: 3722 words>=2: 3624
# all words num: 124926
# all words num: 124828
# 3624
# 3624
#                                 0                                     1  \
# ラベルid                           0                                     1
# ラベルname  quick consensus building  conflict-oriented consensus building
#
#                2                                        3      4            5  \
# ラベルid          2                                        3      4            5
# ラベルname  summary  integration-oriented consensus building  blank  elicitation
#
#                        6
# ラベルid                  6
# ラベルname  externalization

# %%
of = open("data/Social_FA_edu_data.txt", "w")
for i, (sen, lb) in enumerate(zip(np.array(doc), input_data[:, label])):
    sen_str = "".join([str(wd_to_id[wd]) + " " for wd in sen])
    print_str = str(lb_to_id[lb]) + " " + str(lb_to_id[lb]) + " " + sen_str
    print(print_str, file=of)
of.close()

of = open("data/Social_FA_edu_data_pre.txt", "w")
for i, sen in enumerate(np.array(doc_pre)):
    sen_str = "".join([str(wd_to_id[wd]) + " " for wd in sen])
    print(sen_str, file=of)
of.close()

print(max([len(sen) for sen in doc]))

print(KIND)
# Out:
# 203
# 7

# %% [markdown]
# # train
