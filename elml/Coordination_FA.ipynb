# %%
import numpy as np
import math
import pickle
from openpyxl import Workbook
from openpyxl import load_workbook
import mojimoji
import numpy as np
import glob
import re
import MeCab
import types
import pandas as pd
from collections import Counter
# %matplotlib inline

mc = MeCab.Tagger("-Ochasen")

# %%
dirpath = "data/excel/"

filename = "A_W_171116.xlsx"
A_W_171116_excel = pd.ExcelFile(dirpath + filename)
sheet_name = A_W_171116_excel.sheet_names[0]
A_W_171116_df = A_W_171116_excel.parse(sheet_name)

filename = "A_W_171128.xlsx"
A_W_171128_excel = pd.ExcelFile(dirpath + filename)
sheet_name = A_W_171128_excel.sheet_names[0]
A_W_171128_df = A_W_171128_excel.parse(sheet_name)

filename = "171116.xlsx"
S_H_171116_excel = pd.ExcelFile(dirpath + filename)
sheet_name = S_H_171116_excel.sheet_names[0]
S_H_171116_df = S_H_171116_excel.parse(sheet_name)

filename = "2015斉藤.xlsx"
S_2015_excel = pd.ExcelFile(dirpath + filename)
sheet_name = S_2015_excel.sheet_names[0]
S_2015_df = S_2015_excel.parse(sheet_name)

# %% [markdown]
# ## 必要なデータ
# - id
#     - A_W_YYMMDDのNo.(0列目)
#     - SH_171116のid(0列目)
#     - 斉藤2015の発言番号(0列目)
# - reply
#     - A_W_YYMMDDの返信元(1列目)
#     - SH_171116のreply(3列目)
#     - 斉藤2015の返信元(1列目)
# - group
#     - A_W_YYMMDDのgid(6列目)
#     - SH_171116のgid(5列目)
#     - 斉藤2015のグループ番号(6列目)
# - who
#     - A_W_YYMMDDのニックネーム(8列目)
#     - SH_171116のcname(6列目)
#     - 斉藤2015のニックネーム(8列目)
# - body
#     - A_W_YYMMDDの発言内容(11列目)
#     - SH_171116のbody(8列目)
#     - 斉藤2015の発言内容(11列目)
# - epistemic_a
#     - A_W_YYMMDDのEpistemic(A)(12列目)
#     - Epistemic(H)(9列目)
# - epistemic_b
#     - A_W_YYMMDDのWatanabe(13列目)
#     - Epistemic(S)(10列目)
# - coordination_a
#     - A_W_YYMMDDのCoordination(A)(17列目)
#     - SH_171116のCoordination(H)(13列目)
# - coordination_b
#     - A_W_YYMMDDのWatanabe.1(18列目)
#     - SH_171116のCoordination(S)(14列目)
#
# ## 各dfで必要な列
# - A_W_YYMMDD[0, 1, 6, 8, 11, 12, 13, 17, 18]
# - SH_171116[0, 3, 5, 6, 8, 9. 10 13, 14]
# - 斉藤2015[0, 1, 6, 8, 11]

# %%
A_W_YYMMDD_use = [0, 1, 6, 8, 11, 12, 13, 17, 18]
S_H_171116_use = [0, 3, 5, 6, 8, 9, 10, 13, 14]
S_2015_use = [0, 1, 6, 8, 11]

# %%
# A_W_YYMMDDの列名の統合
A_W_171116_df.columns = A_W_171128_df.columns

delete_columns_list = []
for i, column in enumerate(A_W_171116_df):
    if not i in A_W_YYMMDD_use:
        delete_columns_list.append(column)
        
A_W_171116_df = A_W_171116_df.drop(delete_columns_list, axis=1)
A_W_171128_df = A_W_171128_df.drop(delete_columns_list, axis=1)

delete_columns_list = []
for i, column in enumerate(S_H_171116_df):
    if not i in S_H_171116_use:
        delete_columns_list.append(column)
S_H_171116_df = S_H_171116_df.drop(delete_columns_list, axis=1)

delete_columns_list = []
for i, column in enumerate(S_2015_df):
    if not i in S_2015_use:
        delete_columns_list.append(column)
S_2015_df = S_2015_df.drop(delete_columns_list, axis=1)

# %%
print(not False in S_H_171116_df['id'].values == S_2015_df['発言番号'].values)
print(not False in S_H_171116_df['cname'].values == S_2015_df['ニックネーム'].values)
print(not False in S_H_171116_df['body'].values == S_2015_df['発言内容'].values)
# Out:
# True
# True
# True

# %%
S_H_171116_df["reply"] = S_2015_df['返信元']
S_H_171116_df["gid"] = S_2015_df['グループ番号']
concat_border = 299
A_W_171116_df = A_W_171116_df[0:concat_border]
A_W_171128_df = A_W_171128_df[concat_border:]
A_W_df = pd.concat([A_W_171116_df, A_W_171128_df])

# %%
# 要素含まれるNanの数を確認
A_W_df.isnull().sum()
# Out:
# No.                   3
# 返信元                   3
# gid                   3
# ニックネーム                3
# 発言内容                  3
# Epistemic(A)          3
# Watanabe              3
# Coordination(A)    3603
# Watanabe.1         4294
# dtype: int64

# %% [markdown]
# # 重要！！

# %%
# A_W_dfの人間が付けたラベル列のNanをBlankに変換
A_W_df = A_W_df.fillna('Blank')
# 要素にNanが含まれる列を再確認
A_W_df.isnull().any()
# Out:
# No.                False
# 返信元                False
# gid                False
# ニックネーム             False
# 発言内容               False
# Epistemic(A)       False
# Watanabe           False
# Coordination(A)    False
# Watanabe.1         False
# dtype: bool

# %%
# 要素に含まれるNanの数を確認
S_H_171116_df.isnull().sum()
# Out:
# id                    0
# reply                 0
# gid                   0
# cname                 0
# body                  0
# Epistemic(H)          1
# Epistemic(S)          4
# Coordination(H)    3933
# Coordination(S)    4188
# dtype: int64

# %% [markdown]
# # 重要！！

# %%
# S_H_171116_dfの人間が付けたラベル列のNanを取り除く
S_H_171116_df = S_H_171116_df.fillna('Blank')
# 要素にNanが含まれる列を再確認
S_H_171116_df.isnull().any()
# Out:
# id                 False
# reply              False
# gid                False
# cname              False
# body               False
# Epistemic(H)       False
# Epistemic(S)       False
# Coordination(H)    False
# Coordination(S)    False
# dtype: bool

# %% [markdown]
# # 重要！！

# %%
A_W_df = A_W_df.drop_duplicates(subset=['ニックネーム', '発言内容'])
S_H_171116_df = S_H_171116_df.drop_duplicates(subset=['cname', 'body'])

# %% [markdown]
# # 重要！！

# %%
# 表記ゆれの修正と確認
A_W_df['Coordination(A)'] = A_W_df['Coordination(A)'].str.lower()
counter = Counter(A_W_df['Coordination(A)'])
print(counter)
A_W_df['Watanabe.1'] = A_W_df['Watanabe.1'].str.lower()
counter = Counter(A_W_df['Watanabe.1'])
print(counter)
# Out:
# Counter({'blank': 3347, 'technical coordination': 766, 'proceedings': 261, 'task division': 160, 'time management': 54, 'quote': 16})
# Counter({'blank': 3978, 'technical coordination': 306, 'proceedings': 208, 'task division': 75, 'time management': 24, 'quote': 13})

# %% [markdown]
# # 重要！！

# %%
# 表記ゆれの確認
S_H_171116_df['Coordination(S)'] = S_H_171116_df['Coordination(S)'].str.lower()
counter = Counter(S_H_171116_df['Coordination(S)'])
print(counter)
S_H_171116_df['Coordination(H)'] = S_H_171116_df['Coordination(H)'].str.lower()
counter = Counter(S_H_171116_df['Coordination(H)'])
print(counter)
# Out:
# Counter({'blank': 3911, 'technical coordination': 600, 'proceedings': 126, 'time management': 62, 'quote': 26, 'task division': 14})
# Counter({'blank': 3663, 'technical coordination': 780, 'proceedings': 219, 'time management': 35, 'quote': 30, 'task division': 12})

# %%
# 表記ゆれの修正と確認
A_W_df['Epistemic(A)'] = A_W_df['Epistemic(A)'].str.lower()
counter = Counter(A_W_df['Epistemic(A)'])
print(counter)
A_W_df['Watanabe'] = A_W_df['Watanabe'].str.lower()
counter = Counter(A_W_df['Watanabe'])
print(counter)
# Out:
# Counter({'off task': 2392, 'on task': 2092, 'no sense': 119, 'blank': 1})
# Counter({'off task': 2444, 'on task': 2148, 'no sense': 11, 'blank': 1})

# %%
# 表記ゆれの確認
S_H_171116_df['Epistemic(S)'] = S_H_171116_df['Epistemic(S)'].str.lower()
counter = Counter(S_H_171116_df['Epistemic(S)'])
print(counter)
S_H_171116_df['Epistemic(H)'] = S_H_171116_df['Epistemic(H)'].str.lower()
counter = Counter(S_H_171116_df['Epistemic(H)'])
print(counter)
# Out:
# Counter({'off task': 2546, 'on task': 2179, 'no sense': 10, 'blank': 4})
# Counter({'off task': 2560, 'on task': 2165, 'no sense': 13, 'blank': 1})

# %%
A_W_df = A_W_df[A_W_df['Epistemic(A)'] != 'no sense']
A_W_df = A_W_df[A_W_df['Watanabe'] != 'no sense']
A_W_df = A_W_df[A_W_df['Epistemic(A)'] != 'blank']
A_W_df = A_W_df[A_W_df['Watanabe'] != 'blank']
print(Counter(A_W_df['Epistemic(A)']))
print(Counter(A_W_df['Watanabe']))
# Out:
# Counter({'off task': 2390, 'on task': 2091})
# Counter({'off task': 2337, 'on task': 2144})

# %%
S_H_171116_df = S_H_171116_df[S_H_171116_df['Epistemic(H)'] != 'no sense']
S_H_171116_df = S_H_171116_df[S_H_171116_df['Epistemic(S)'] != 'no sense']
S_H_171116_df = S_H_171116_df[S_H_171116_df['Epistemic(H)'] != 'blank']
S_H_171116_df = S_H_171116_df[S_H_171116_df['Epistemic(S)'] != 'blank']
print(Counter(S_H_171116_df['Epistemic(H)']))
print(Counter(S_H_171116_df['Epistemic(S)']))
# Out:
# Counter({'off task': 2558, 'on task': 2158})
# Counter({'off task': 2538, 'on task': 2178})

# %% [markdown]
# # 重要！！

# %%
A_W_match_df = A_W_df[A_W_df['Coordination(A)'] == A_W_df['Watanabe.1']].reset_index(drop=True)
A_W_match_df.head()
# Out:
#    No. 返信元 gid ニックネーム                          発言内容 Epistemic(A)  Watanabe  \
# 0    1  \N   1   まこぴす                   よろしくお願いします！     off task  off task
# 1   31  \N   1      哲                    よろしくお願いします     off task  off task
# 2   70  \N   1     仙波  名前なのが恥ずかしいです…\n\nよろしくお願いします！     off task  off task
# 3  119  \N   1   まこぴす                早速課題やっちゃいましょう！     off task  off task
# 4  163  \N   1     仙波     やっちゃいましょう\n\nmoodleはゴミです！      on task   on task
#
#   Coordination(A)   Watanabe.1
# 0           blank        blank
# 1           blank        blank
# 2           blank        blank
# 3     proceedings  proceedings
# 4           blank        blank

# %% [markdown]
# # 重要！！

# %%
S_H_match_df = S_H_171116_df[S_H_171116_df['Coordination(H)'] == S_H_171116_df['Coordination(S)']].reset_index(drop=True)
S_H_match_df.head()
# Out:
#      id reply  gid   cname                body Epistemic(H) Epistemic(S)  \
# 0  1593    \N    1  世界のわたべ         よろしくお願いします。     off task     off task
# 1  1598    \N    1    ざきさん              よろしくです     off task     off task
# 2  1606    \N    1       あ              よろしくです     off task     off task
# 3  1659    \N    1    ざきさん  みなさんファイルをアップしましたか？     off task     off task
# 4  1704    \N    1    ざきさん              名前バレｗｗ     off task     off task
#
#           Coordination(H)         Coordination(S)
# 0                   blank                   blank
# 1                   blank                   blank
# 2                   blank                   blank
# 3  technical coordination  technical coordination
# 4                   blank                   blank

# %%
A_W_match_df.isnull().sum()
# Out:
# No.                0
# 返信元                0
# gid                0
# ニックネーム             0
# 発言内容               0
# Epistemic(A)       0
# Watanabe           0
# Coordination(A)    0
# Watanabe.1         0
# dtype: int64

# %%
S_H_match_df.isnull().sum()
# Out:
# id                 0
# reply              0
# gid                0
# cname              0
# body               0
# Epistemic(H)       0
# Epistemic(S)       0
# Coordination(H)    0
# Coordination(S)    0
# dtype: int64

# %% [markdown]
# # 重要！！

# %%
header = ['id', 'reply', 'group_id', 'cname', 'body', 'Epistemic_A', 'Epistemic_B', 'Coordination_A', 'Coordination_B']
A_W_df.columns = header
S_H_171116_df.columns = header
A_W_match_df.columns = header
S_H_match_df.columns = header
All_df = pd.concat([A_W_df, S_H_171116_df], ignore_index=True)
match_df = pd.concat([A_W_match_df, S_H_match_df], ignore_index=True)
print(match_df.shape[0]/All_df.shape[0] *100)
print(A_W_df.shape)
print(S_H_171116_df.shape)
print(All_df.shape)
print(match_df.shape)
# Out:
# 83.21191692943351
# (4481, 9)
# (4716, 9)
# (9197, 9)
# (7653, 9)

# %%
# データの形式の定義
data_format = ['id', 'reply', 'group_id', 'cname', 'body', 'epistemic', 'label']
# 名前からデータのindexに変換する辞書
data_index = {column : i for i, column in enumerate(data_format)}
print(data_index)

id = 0
reply = 1
group_id = 2
cname = 3
body = 4
epistemic = 5
label = 6

df_index = {column: i for i, column in enumerate(All_df)}
print(df_index)
# Out:
# {'label': 6, 'epistemic': 5, 'cname': 3, 'body': 4, 'id': 0, 'reply': 1, 'group_id': 2}
# {'Epistemic_B': 6, 'cname': 3, 'body': 4, 'Coordination_B': 8, 'id': 0, 'reply': 1, 'Coordination_A': 7, 'group_id': 2, 'Epistemic_A': 5}

# %% [markdown]
# # 重要！！

# %%
df_use = [0, 1, 2, 3, 4]

# All_df_index['ラベル名']を変更して取り出すラベルを分ける
# epistemic_position = df_index['Epistemic_A']
# epistemic_position = df_index['Epistemic_B']
epistemic_position = df_index['Epistemic_B']
df_use.append(epistemic_position)

# label_position = df_index['Coordination_A']
# label_position = df_index['Coordination_B']
label_position = df_index['Coordination_B']
df_use.append(label_position)

print(df_use)

delete_columns_list = []
# for i, column in enumerate(All_df):
for i, column in enumerate(match_df):
    if not i in df_use:
        delete_columns_list.append(column)
# input_df = All_df.drop(delete_columns_list, axis=1)
input_df = match_df.drop(delete_columns_list, axis=1)
# input_df = A_W_consulted_df.drop(delete_columns_list, axis=1)
input_df.columns = data_format
# Out:
# [0, 1, 2, 3, 4, 6, 8]

# %%
input_df
# Out:
#         id reply group_id cname  \
# 0        1    \N        1  まこぴす
# 1       31    \N        1     哲
# 2       70    \N        1    仙波
# 3      119    \N        1  まこぴす
# 4      163    \N        1    仙波
# 5      194    \N        1  まこぴす
# 6      302    \N        1     哲
# 7      309    \N        1    仙波
# 8      385    \N        1  まこぴす
# 9      426    \N        1  まこぴす
# 10     500    \N        1    仙波
# 11     528    \N        1    仙波
# 12     693    \N        1  まこぴす
# 13     715    \N        1    仙波
# 14     791    \N        1    仙波
# 15     813    \N        1  まこぴす
# 16     830   746        1     哲
# 17     831    \N        1    仙波
# 18     851   813        1     哲
# 19     888    \N        1    仙波
# 20     916    \N        1    仙波
# 21     934   899        1     哲
# 22     964    \N        1  まこぴす
# 23     990    \N        1    仙波
# 24    1017    \N        1    \N
# 25    1031    \N        1  まこぴす
# 26    1048    \N        1    仙波
# 27    1066    \N        1     哲
# 28    1101    \N        1    仙波
# 29    1107    \N        1  まこぴす
# ...    ...   ...      ...   ...
# 7623  6117  6084    10001  オノヅカ
# 7624  6121    \N    10001   みずき
# 7625  6131  6081    10001   みずき
# 7626  6142  6117    10001   まささ
# 7627  6170  6141    10001   みずき
# 7628  6171  6142    10001  オノヅカ
# 7629  6183    \N    10001  オノヅカ
# 7630  6224    \N    10001  オノヅカ
# 7631  6243    \N    10001  オノヅカ
# 7632  6254    \N    10001  オノヅカ
# 7633  6257  6254    10001   まささ
# 7634  6264  6254    10001   みずき
# 7635  6266    \N    10001  オノヅカ
# 7636  6288    \N    10001  オノヅカ
# 7637  6326    \N    10001  オノヅカ
# 7638  6347    \N    10001   みずき
# 7639  6363    \N    10001   まささ
# 7640  6397    \N    10001  オノヅカ
# 7641  6415    \N    10001   まささ
# 7642  6435  6415    10001   みずき
# 7643  6436    \N    10001  オノヅカ
# 7644  6441  6436    10001   みずき
# 7645  6443  6436    10001   まささ
# 7646  6451  6443    10001   みずき
# 7647  6459    \N    10001   みずき
# 7648  6463  6459    10001   まささ
# 7649  6467  6459    10001  オノヅカ
# 7650  6477    \N    10001  オノヅカ
# 7651  6491  6477    10001   まささ
# 7652  6521    \N    10001  オノヅカ
#
#                                                    body epistemic  \
# 0                                           よろしくお願いします！  off task
# 1                                            よろしくお願いします  off task
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！  off task
# 3                                        早速課題やっちゃいましょう！  off task
# 4                             やっちゃいましょう\n\nmoodleはゴミです！   on task
# 5                                            使いにくいです(笑)   on task
# 6                                                  同意です   on task
# 7     以前インタラクティブアート受講していたのですが、その時に課題が不具合で出せなくなっていた時期...   on task
# 8     学習環境として必要最低限の機能は備えていると思うが、操作性の面ではPCの最低限の知識があるこ...   on task
# 9                                           自分の意見です！(笑)   on task
# 10                                             ほぼほぼ同意です   on task
# 11                                    他に何か考えてることなどありますか   on task
# 12                                          他に意見ありますかー？   on task
# 13                                              自分はないです   on task
# 14                  まこびすさんがいい感じにまとめてくれたので自分はこれでいいと思います！   on task
# 15                             １度共有テキスト全部消して現在の回答案書きます！  off task
# 16                       > 哲さんどうですか？\n\n自分もみなさんの意見に同意です   on task
# 17                                                 了解です   on task
# 18                                           ありがとうございます   on task
# 19                                    あざっす\n\nこれでいいのでは？   on task
# 20                                              自分は平気です  off task
# 21                                          よろしくお願いします！  off task
# 22                                                完了です！  off task
# 23                                              お疲れ様です！  off task
# 24                                           １番乗りおめでとう！  off task
# 25                                        ありがとうございます(笑)  off task
# 26                                                  でた！  off task
# 27                       お役に立てず申し訳ございません\n\nありがとうごいました！  off task
# 28                        お疲れ様でした！\n\nまた何かあればその時はよろしくです  off task
# 29                                       いえいえ！お疲れさまでした！  off task
# ...                                                 ...       ...
# 7623  これを少し削った感じでいいと思います\n\n> 異なるLMS間で教材の互換性がなかったものを...   on task
# 7624              さまざまなLMSに同一の学習コンテンツを動作させるための国際標準規格です。   on task
# 7625  > プラットフォーム上で教材のデータを共有するやりとりとそのインターフェースの規定の標準規格...   on task
# 7626  > これを少し削った感じでいいと思います\n\n> \n\n> &gt; 異なるLMS間で教...   on task
# 7627                              > まとめちゃいましょう\n\n了解です！  off task
# 7628  > &gt; これを少し削った感じでいいと思います\n\n> \n\n> &gt; \n\n...   on task
# 7629                          共有テキストに書いてある感じで提出しちゃいますか？  off task
# 7630                          共有テキストの下半分のやつで出しちゃおうと思ってる  off task
# 7631                                       じゃあ提出しておきますね  off task
# 7632                                             提出しました  off task
# 7633                             > 提出しました\nありがとうございます！！  off task
# 7634                              > 提出しました\nありがとうございます！  off task
# 7635                                   共有テキスト一回消しちゃいます？  off task
# 7636             TinCanとは多種多様な学習活動の履歴を記録・検索・抽出するためのしすてむ   on task
# 7637                        SCORMの次世代版でビッグデータにも対応してるらしい   on task
# 7638  LMSに依存することなくあらゆる学習についての記録ができるため、さまざまな活用方法を期待する...   on task
# 7639                               スマホアプリやタブレットでの利用もできる   on task
# 7640                                            あと位置づけか  off task
# 7641  次世代SCORMとして発表された規格で、正式名称はExperience API（略称：xAP...   on task
# 7642  > 次世代SCORMとして発表された規格で、正式名称はExperience API（略称：x...   on task
# 7643                                    共有テキストので良いと思います  off task
# 7644                         > 共有テキストので良いと思います\n大丈夫ですか？  off task
# 7645           > 共有テキストので良いと思います\n私もそう思います、分かりやすくていいです！  off task
# 7646  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...  off task
# 7647                                         課題2提出完了です！  off task
# 7648                          > 課題2提出完了です！\nありがとうございます！  off task
# 7649                           > 課題2提出完了です！\nありがとうございます  off task
# 7650                                           課題3やりますか  off task
# 7651              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね  off task
# 7652                            「何を」の部分の選択肢が後1つくらい欲しいかな  off task
#
#                        label
# 0                      blank
# 1                      blank
# 2                      blank
# 3                proceedings
# 4                      blank
# 5                      blank
# 6                      blank
# 7                      blank
# 8                      blank
# 9                      blank
# 10                     blank
# 11                     blank
# 12                     blank
# 13                     blank
# 14                     blank
# 15    technical coordination
# 16                     blank
# 17                     blank
# 18                     blank
# 19                     blank
# 20                     blank
# 21                     blank
# 22    technical coordination
# 23                     blank
# 24                     blank
# 25                     blank
# 26                     blank
# 27                     blank
# 28                     blank
# 29                     blank
# ...                      ...
# 7623                   blank
# 7624                   blank
# 7625                   blank
# 7626                   blank
# 7627                   blank
# 7628                   blank
# 7629  technical coordination
# 7630  technical coordination
# 7631  technical coordination
# 7632  technical coordination
# 7633                   blank
# 7634                   blank
# 7635  technical coordination
# 7636                   blank
# 7637                   blank
# 7638                   blank
# 7639                   blank
# 7640                   blank
# 7641                   blank
# 7642                   blank
# 7643                   blank
# 7644                   blank
# 7645                   blank
# 7646  technical coordination
# 7647  technical coordination
# 7648                   blank
# 7649                   blank
# 7650             proceedings
# 7651  technical coordination
# 7652                   blank
#
# [7653 rows x 7 columns]

# %%
input_df = input_df[input_df['epistemic'] == 'off task'].reset_index(drop=True)
input_df
# Out:
#         id reply group_id     cname  \
# 0        1    \N        1      まこぴす
# 1       31    \N        1         哲
# 2       70    \N        1        仙波
# 3      119    \N        1      まこぴす
# 4      813    \N        1      まこぴす
# 5      916    \N        1        仙波
# 6      934   899        1         哲
# 7      964    \N        1      まこぴす
# 8      990    \N        1        仙波
# 9     1017    \N        1        \N
# 10    1031    \N        1      まこぴす
# 11    1048    \N        1        仙波
# 12    1066    \N        1         哲
# 13    1101    \N        1        仙波
# 14    1107    \N        1      まこぴす
# 15      27    \N        2       マニン
# 16      90    \N        2   Houdini
# 17      91    \N        2      あひるぅ
# 18     174    \N        2      あひるぅ
# 19     184   174        2       マニン
# 20     199   184        2      あひるぅ
# 21     441    \N        2   Houdini
# 22     631    \N        2   Houdini
# 23    1177    \N        2      あひるぅ
# 24    1465    \N        2       マニン
# 25    1476    \N        2   Houdini
# 26    1486    \N        2      あひるぅ
# 27      86    \N        3     match
# 28      97    \N        3     kouta
# 29     133    \N        3       いつき
# ...    ...   ...      ...       ...
# 3480  6482    \N        2       まろん
# 3481  6505  6482        2        ノラ
# 3482  6588    \N        2        ノラ
# 3483  6594    \N        2       まろん
# 3484  6599    \N        2  H.Yamato
# 3485  5974    \N    10001      オノヅカ
# 3486  5975    \N    10001       まささ
# 3487  5978    \N    10001       みずき
# 3488  6001    \N    10001      オノヅカ
# 3489  6019  6001    10001       みずき
# 3490  6035    \N    10001       みずき
# 3491  6170  6141    10001       みずき
# 3492  6183    \N    10001      オノヅカ
# 3493  6224    \N    10001      オノヅカ
# 3494  6243    \N    10001      オノヅカ
# 3495  6254    \N    10001      オノヅカ
# 3496  6257  6254    10001       まささ
# 3497  6264  6254    10001       みずき
# 3498  6266    \N    10001      オノヅカ
# 3499  6397    \N    10001      オノヅカ
# 3500  6436    \N    10001      オノヅカ
# 3501  6441  6436    10001       みずき
# 3502  6443  6436    10001       まささ
# 3503  6451  6443    10001       みずき
# 3504  6459    \N    10001       みずき
# 3505  6463  6459    10001       まささ
# 3506  6467  6459    10001      オノヅカ
# 3507  6477    \N    10001      オノヅカ
# 3508  6491  6477    10001       まささ
# 3509  6521    \N    10001      オノヅカ
#
#                                                    body epistemic  \
# 0                                           よろしくお願いします！  off task
# 1                                            よろしくお願いします  off task
# 2                          名前なのが恥ずかしいです…\n\nよろしくお願いします！  off task
# 3                                        早速課題やっちゃいましょう！  off task
# 4                              １度共有テキスト全部消して現在の回答案書きます！  off task
# 5                                               自分は平気です  off task
# 6                                           よろしくお願いします！  off task
# 7                                                 完了です！  off task
# 8                                               お疲れ様です！  off task
# 9                                            １番乗りおめでとう！  off task
# 10                                        ありがとうございます(笑)  off task
# 11                                                  でた！  off task
# 12                       お役に立てず申し訳ございません\n\nありがとうごいました！  off task
# 13                        お疲れ様でした！\n\nまた何かあればその時はよろしくです  off task
# 14                                       いえいえ！お疲れさまでした！  off task
# 15                                                よろしくー  off task
# 16                                                よろしゅー  off task
# 17                                           おはようございました  off task
# 18                                        ていうか帰りませんか？？？  off task
# 19                        > ていうか帰りませんか？？？\n\nどうぞお帰りください  off task
# 20    > &gt; ていうか帰りませんか？？？\n\n\n\n> どうぞお帰りください\n\n\n...  off task
# 21                                     はやくも自分の発言が消えるバグが  off task
# 22             共有テキストのテストしてみます\n\n課題「Moodleの考察」の例文コピペです  off task
# 23                            自分なりに共有で意見をまとめてましたが、出てます？  off task
# 24                                                 お疲れー  off task
# 25                                               お疲れ様です  off task
# 26                                              おつかれでした  off task
# 27                                          よろしくお願いします。  off task
# 28                                   koutaです、よろしくお願いします  off task
# 29                                          よろしくお願いします。  off task
# ...                                                 ...       ...
# 3480  個人課題なので話し合って、良い意見だなと思えば自分の意見に追加すればいいのではないかな\nと...  off task
# 3481  > 個人課題なので話し合って、良い意見だなと思えば自分の意見に追加すればいいのではないかな\...  off task
# 3482                                           お疲れ様でしたー  off task
# 3483                           それではお疲れさまです。ありがとうございました。  off task
# 3484                                          お疲れさまでした。  off task
# 3485                                                どうも  off task
# 3486                                         よろしくお願いします  off task
# 3487                                         よろしくお願いします  off task
# 3488                             SCORMについて簡単にまとめちゃいましょう  off task
# 3489                 > SCORMについて簡単にまとめちゃいましょう\nそうしましょう！  off task
# 3490                             直接共有テキストに入力しちゃっていいですか？  off task
# 3491                              > まとめちゃいましょう\n\n了解です！  off task
# 3492                          共有テキストに書いてある感じで提出しちゃいますか？  off task
# 3493                          共有テキストの下半分のやつで出しちゃおうと思ってる  off task
# 3494                                       じゃあ提出しておきますね  off task
# 3495                                             提出しました  off task
# 3496                             > 提出しました\nありがとうございます！！  off task
# 3497                              > 提出しました\nありがとうございます！  off task
# 3498                                   共有テキスト一回消しちゃいます？  off task
# 3499                                            あと位置づけか  off task
# 3500                                    共有テキストので良いと思います  off task
# 3501                         > 共有テキストので良いと思います\n大丈夫ですか？  off task
# 3502           > 共有テキストので良いと思います\n私もそう思います、分かりやすくていいです！  off task
# 3503  > &gt; 共有テキストので良いと思います\n\n> 私もそう思います、分かりやすくていい...  off task
# 3504                                         課題2提出完了です！  off task
# 3505                          > 課題2提出完了です！\nありがとうございます！  off task
# 3506                           > 課題2提出完了です！\nありがとうございます  off task
# 3507                                           課題3やりますか  off task
# 3508              > 課題3やりますか\nやりましょう、共有テキストいったん消しちゃいますね  off task
# 3509                            「何を」の部分の選択肢が後1つくらい欲しいかな  off task
#
#                        label
# 0                      blank
# 1                      blank
# 2                      blank
# 3                proceedings
# 4     technical coordination
# 5                      blank
# 6                      blank
# 7     technical coordination
# 8                      blank
# 9                      blank
# 10                     blank
# 11                     blank
# 12                     blank
# 13                     blank
# 14                     blank
# 15                     blank
# 16                     blank
# 17                     blank
# 18                     blank
# 19                     blank
# 20                     blank
# 21                     blank
# 22    technical coordination
# 23    technical coordination
# 24                     blank
# 25                     blank
# 26                     blank
# 27                     blank
# 28                     blank
# 29                     blank
# ...                      ...
# 3480  technical coordination
# 3481  technical coordination
# 3482                   blank
# 3483                   blank
# 3484                   blank
# 3485                   blank
# 3486                   blank
# 3487                   blank
# 3488             proceedings
# 3489                   blank
# 3490  technical coordination
# 3491                   blank
# 3492  technical coordination
# 3493  technical coordination
# 3494  technical coordination
# 3495  technical coordination
# 3496                   blank
# 3497                   blank
# 3498  technical coordination
# 3499                   blank
# 3500                   blank
# 3501                   blank
# 3502                   blank
# 3503  technical coordination
# 3504  technical coordination
# 3505                   blank
# 3506                   blank
# 3507             proceedings
# 3508  technical coordination
# 3509                   blank
#
# [3510 rows x 7 columns]

# %%
counter = Counter(input_df['label'])
print(counter)
# Out:
# Counter({'blank': 2502, 'technical coordination': 712, 'proceedings': 227, 'time management': 36, 'quote': 21, 'task division': 12})

# %%
input_data = input_df.values

# %%
def preprocess(xs, trim_citation=False):
    zs = [""] * len(xs)
    '''全角空白'''
    for i, l in enumerate(xs):
        xs[i] = re.sub('　', ' ', str(l))
    '''多重引用'''
    for i, l in enumerate(xs):
        xs[i] = re.sub('＆ｇｔ；', '＞', l)
    '''引用部分は除外'''
    count_refer = 0
    for i, l in enumerate(xs):
        sen = ""
        have_refer = 1
        for x in l.split('\n'):
            if len(x) == 0:
                continue
            elif x[0].encode('utf-8') == '＞'.encode('utf-8'):
                have_refer = 1
                x = x[1:]
                if len(x) > 0 and x[0].encode('utf-8') != '＞'.encode('utf-8') and \
                        x[0:2].encode('utf-8') != ' ＞'.encode('utf-8') and x != ' ':
                    if trim_citation:
                        zs[i] += x + '\n'
                    else:
                        sen = sen + "＞ " + x + '\n'
                continue
            else:
                sen = sen + x + '\n'
        xs[i] = sen.strip()
        count_refer += have_refer
    '''顔文字'''
    pat = re.compile('（[^ぁ-んァ-ン一-龠]+?）', re.U)
    for i, l in enumerate(xs):
        xs[i] = re.sub(pat, ' KAOMOJI ', l)
    '''日本語及び記号{？！ー〜。、} のみ有効'''
    pat = re.compile('[^＞ Ａ-Ｚａ-ｚ０-９ぁ-んァ-ン一-龠？！ー〜。、\n]+?', re.U)
    for i, l in enumerate(xs):
        xs[i] = re.sub(pat, '', l)
    '''記号繰り返し'''
    pat_1 = re.compile('[ｗ]{1,}', re.U)
    pat_2 = re.compile('[？]{1,}', re.U)
    pat_3 = re.compile('[！]{1,}', re.U)
    pat_4 = re.compile('[～]{1,}', re.U)
    pat_5 = re.compile('[ー]{1,}', re.U)
    pat_6 = re.compile('[。]{1,}', re.U)

    for i, l in enumerate(xs):
        l = re.sub(pat_1, 'ｗ', l)
        l = re.sub(pat_2, '？', l)
        l = re.sub(pat_3, '！', l)
        l = re.sub(pat_4, '～', l)
        l = re.sub(pat_5, 'ー', l)
        l = re.sub(pat_6, '。', l)
        xs[i] = l

    if trim_citation:
        return zs
    else:
        return None

# %%
def make_xs(orig, trim_citation=False, use_seq2seq=False):

    tmp = np.copy(orig)
    xs = tmp[:, body]
    zs = preprocess(xs, trim_citation=(trim_citation or use_seq2seq))

    if use_seq2seq:
        tmp_prev = np.roll(tmp, 1, axis=0)
        tmp_prev[0, 0] = ""
        ts = tmp[:, [1, 2]]
        xs_prev = tmp_prev[:, body]

        for i in range(len(tmp)):
            if tmp[i, group_id] != tmp_prev[i, group_id]:  # group が異なる
                xs_prev[i] = ""
        preprocess(xs_prev, trim_citation=True)

        for i in range(len(xs)):
            replay_to = tmp[i, 2]
            if zs[i] != "":
                xs_prev[i] = zs[i]
            elif replay_to != -1:
                a = xs[:i][tmp[:i, 1] == replay_to]
                if len(a) != 0:
                    xs_prev[i] = a[-1]

        return xs, xs_prev
    else:
        return xs

# %%
def get_doc(xs):
    doc = []
    for ll in xs:
        sen = []
        for l in ll.split('\n'):
            for w in mc.parse(l).split('\n'):
                mx = w.split('\t')
                if len(mx[0]) > 0:
                    sen.append(mx[0])
        doc.append(sen)
    return doc

# %%
xs, xs_pre = make_xs(input_data, trim_citation=True, use_seq2seq=True)
doc = get_doc(xs)
doc_pre = get_doc(xs_pre)
for i in doc[:10]:
    print(" ".join(i))
# Out:
# よろしく お願い し ます ！ EOS
# よろしく お願い し ます EOS
# 名前 な の が 恥ずかしい です EOS よろしく お願い し ます ！ EOS
# 早速 課題 やっ ちゃ い ましょ う ！ EOS
# １ 度 共有 テキスト 全部 消し て 現在 の 回答 案 書き ます ！ EOS
# 自分 は 平気 です EOS
# よろしく お願い し ます ！ EOS
# 完了 です ！ EOS
# お疲れ様 です ！ EOS
# １ 番 乗り おめでとう ！ EOS

# %%
wd_set = Counter([x for sen in doc + doc_pre for x in sen])
wd_ary = np.array(list(wd_set.keys()))
wd_cnt = np.array(list(wd_set.values()))
wd_ary = wd_ary[np.argsort(wd_cnt)[::-1]]
wd_cnt.sort()
wd_cnt = wd_cnt[::-1]
wd_to_id = {wd: i for i, wd in enumerate(wd_ary)}
lb_to_id = {lb: i for i, lb in enumerate({x for x in input_data[:, label]})}
id_to_wd = {wd_to_id[wd]: wd for wd in wd_to_id.keys()}
id_to_lb = {lb_to_id[lb]: lb for lb in lb_to_id.keys()}
for i in range(10):
    print(list(wd_ary)[i], list(wd_cnt)[i])
    #print(list(wd_set.keys())[i], list(wd_set.values())[i])
# Out:
# EOS 9349
# ます 2630
# た 2533
# し 2082
# て 1916
# です 1903
# の 1892
# ！ 1744
# か 1614
# ？ 1308

# %% [markdown]
# # 重要！！

# %%
KIND = len(list(lb_to_id.keys()))
CUT_OFF = 2

print("words kinds:",
      len(wd_cnt), "words>=" + str(CUT_OFF) + ":", np.sum(wd_cnt >= CUT_OFF))
print("all words num:", np.sum(wd_cnt))
print("all words num:", np.sum(wd_cnt[wd_cnt >= CUT_OFF]))

other_id = np.sum(wd_cnt >= CUT_OFF)
wd_to_id.update({wd: other_id for wd in wd_ary[wd_cnt < CUT_OFF]})
print(other_id)
id_to_wd[other_id] = '[X]'

print(max(wd_to_id.values()))

with open('data/Coordination_FA_id_to_wd.pickle', mode='wb') as f:
    pickle.dump(id_to_wd, f)
with open('data/Coordination_FA_wd_to_id.pickle', mode='wb') as f:
    pickle.dump(wd_to_id, f)
with open('data/Coordination_FA_wd_set.pickle', mode='wb') as f:
    pickle.dump(wd_set, f)
with open('data/Coordination_FA_id_to_lb.pickle', mode='wb') as f:
    pickle.dump(id_to_lb, f)
pd.DataFrame(
    np.array(list(id_to_lb.items())).T, index=["ラベルid", "ラベルname"])
# Out:
# words kinds: 2393 words>=2: 2344
# all words num: 77841
# all words num: 77792
# 2344
# 2344
#                        0              1            2                       3  \
# ラベルid                  0              1            2                       3
# ラベルname  time management  task division  proceedings  technical coordination
#
#              4      5
# ラベルid        4      5
# ラベルname  blank  quote

# %%
of = open("data/Coordination_FA_edu_data.txt", "w")
for i, (sen, lb) in enumerate(zip(np.array(doc), input_data[:, label])):
    sen_str = "".join([str(wd_to_id[wd]) + " " for wd in sen])
    print_str = str(lb_to_id[lb]) + " " + str(lb_to_id[lb]) + " " + sen_str
    print(print_str, file=of)
of.close()

of = open("data/Coordination_FA_edu_data_pre.txt", "w")
for i, sen in enumerate(np.array(doc_pre)):
    sen_str = "".join([str(wd_to_id[wd]) + " " for wd in sen])
    print(sen_str, file=of)
of.close()

print(max([len(sen) for sen in doc]))

print(KIND)
# Out:
# 313
# 6

# %% [markdown]
# # train
