# %%
# -*- coding: utf-8 -*-
# %matplotlib inline
import numpy as np
import pandas as pd
from collections import Counter
import re
import pickle
import MeCab
mc = MeCab.Tagger("-Ochasen")

# %%
old_excel = pd.ExcelFile("data/excel2/old_result.xlsx")
sheet_name = old_excel.sheet_names[2]
old_df = old_excel.parse(sheet_name)

# %%
old_df
# Out:
#            全体  具体性   工夫  適切性  了承  提案  質問  挨拶  報告  回答  転換  確認  感謝  メタ  依頼  \
# 1         2.0  3.0  3.0  2.0  18  10   5   6   6   2   3   2   0   2   0
# M0116112  NaN  NaN  NaN  NaN   4   4   0   2   2   2   0   1   0   2   0
# M0116139  NaN  NaN  NaN  NaN   7   1   2   2   1   0   1   0   0   0   0
# M0116331  NaN  NaN  NaN  NaN   7   5   3   2   3   0   2   1   0   0   0
# 2         2.0  2.0  2.0  2.0   8  10   9   6   7   5   2   2   0   1   0
# M0116059  NaN  NaN  NaN  NaN   2   2   3   2   1   2   0   0   0   1   0
# M0116209  NaN  NaN  NaN  NaN   4   4   4   2   1   1   0   1   0   0   0
# M0116287  NaN  NaN  NaN  NaN   2   4   2   2   5   2   2   1   0   0   0
# 3         2.0  3.0  2.0  3.0  12   6   8   1   6   7   2   2   2   0   0
# M0116162  NaN  NaN  NaN  NaN   4   1   1   0   0   1   0   0   2   0   0
# M0116184  NaN  NaN  NaN  NaN   4   5   2   0   3   2   0   0   0   0   0
# M0116329  NaN  NaN  NaN  NaN   4   0   5   1   3   4   2   2   0   0   0
# 4         3.0  3.0  3.0  3.0  20  16  10   6  12   7   4   2   2   5   0
# M0116023  NaN  NaN  NaN  NaN   5   5   3   3   4   1   3   1   2   0   0
# M0116076  NaN  NaN  NaN  NaN  13   7   3   2   5   2   0   0   0   3   0
# M0116256  NaN  NaN  NaN  NaN   2   4   4   1   3   4   1   1   0   2   0
# 5         3.0  3.0  3.0  3.0  23  10   7   8   6   2   3   1   0   1   1
# M0116048  NaN  NaN  NaN  NaN   8   3   3   4   4   0   0   1   0   1   1
# M0116150  NaN  NaN  NaN  NaN   5   6   2   2   2   2   2   0   0   0   0
# M0116300  NaN  NaN  NaN  NaN  10   1   2   2   0   0   1   0   0   0   0
# 6         2.0  2.0  2.0  2.0  42  20   9  13   5   9   7   1   1   0   0
# M0116127  NaN  NaN  NaN  NaN  13   6   1   3   1   1   0   0   0   0   0
# M0116306  NaN  NaN  NaN  NaN  18   4   4   4   0   4   1   0   1   0   0
# M0116311  NaN  NaN  NaN  NaN  11  10   4   6   4   4   6   1   0   0   0
# 7         1.0  1.0  1.0  2.0  10  15   7   6   7   5   9   0   1   0   1
# M0116047  NaN  NaN  NaN  NaN   4   6   0   2   0   0   0   0   0   0   1
# M0116165  NaN  NaN  NaN  NaN   4   3   0   1   4   5   3   0   0   0   0
# M0116166  NaN  NaN  NaN  NaN   2   6   7   3   3   0   6   0   1   0   0
# 8         3.0  3.0  3.0  3.0  20  10   8   7  12   1   4   0   4   0   0
# M0116024  NaN  NaN  NaN  NaN   7   3   2   3   4   0   0   0   1   0   0
# ...       ...  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# M0116043  NaN  NaN  NaN  NaN  11   5   1   1   3   2   1   0   2   0   1
# M0116334  NaN  NaN  NaN  NaN   8   5   6   2   4   3   1   3   0   0   0
# 40        3.0  3.0  3.0  3.0  32  11  11   6   6  12   2   4   4   1   0
# M0115011  NaN  NaN  NaN  NaN  10   2   3   2   3   2   1   3   2   0   0
# M0116161  NaN  NaN  NaN  NaN   9   7   4   2   1   5   1   1   1   1   0
# M0116274  NaN  NaN  NaN  NaN  13   2   4   2   2   5   0   0   1   0   0
# 41        1.0  1.0  2.0  2.0  13   5   5   7   5   4   0   2   1   0   2
# M0116018  NaN  NaN  NaN  NaN   8   1   1   1   0   0   0   1   0   0   1
# M0116095  NaN  NaN  NaN  NaN   1   3   2   2   5   1   0   1   0   0   1
# M0116216  NaN  NaN  NaN  NaN   4   1   2   4   0   3   0   0   1   0   0
# 42        1.0  1.0  1.0  2.0   7   5   6   4   5   3   2   2   0   0   0
# M0116019  NaN  NaN  NaN  NaN   3   0   0   1   1   1   2   0   0   0   0
# M0116121  NaN  NaN  NaN  NaN   2   2   5   1   3   2   0   2   0   0   0
# M0116323  NaN  NaN  NaN  NaN   2   3   1   2   1   0   0   0   0   0   0
# 43        1.0  1.0  2.0  1.0  10  21   3   8   5   3   4   3   2   2   1
# M0116033  NaN  NaN  NaN  NaN   4   6   1   2   0   1   0   1   1   0   1
# M0116244  NaN  NaN  NaN  NaN   3  12   2   3   1   1   0   0   0   2   0
# M0116327  NaN  NaN  NaN  NaN   3   3   0   3   4   1   4   2   1   0   0
# 44        2.0  2.0  2.0  2.0  15   6   5   6   4   3   1   1   3   2   3
# M0116083  NaN  NaN  NaN  NaN   1   0   0   1   0   1   0   0   0   1   0
# M0116101  NaN  NaN  NaN  NaN   5   2   5   3   4   2   1   1   0   1   1
# M0116197  NaN  NaN  NaN  NaN   9   4   0   2   0   0   0   0   3   0   2
# 45        1.0  1.0  1.0  1.0  20   9   9   3   7   5   2   2   2   0   0
# M0116071  NaN  NaN  NaN  NaN   6   4   4   1   3   2   2   1   0   0   0
# M0116279  NaN  NaN  NaN  NaN   6   3   3   1   3   2   0   1   1   0   0
# M0116301  NaN  NaN  NaN  NaN   8   2   2   1   1   1   0   0   1   0   0
# 46        2.0  2.0  2.0  2.0  17   9   8   4   1   4   0   1   0   1   0
# M0116011  NaN  NaN  NaN  NaN   3   3   2   1   0   2   0   1   0   0   0
# M0116013  NaN  NaN  NaN  NaN  10   0   2   2   0   2   0   0   0   0   0
# M0116064  NaN  NaN  NaN  NaN   4   6   4   1   1   0   0   0   0   1   0
#
#           ジョーク  ノイズ  訂正   総計  その他
# 1            0    0   0   54    4
# M0116112     0    0   0   17    3
# M0116139     0    0   0   14    0
# M0116331     0    0   0   23    1
# 2            0    0   0   50    3
# M0116059     0    0   0   13    1
# M0116209     0    0   0   17    1
# M0116287     0    0   0   20    1
# 3            0    0   1   47    5
# M0116162     0    0   0    9    2
# M0116184     0    0   1   17    1
# M0116329     0    0   0   21    2
# 4            1    1   0   86   11
# M0116023     1    1   0   29    5
# M0116076     0    0   0   35    3
# M0116256     0    0   0   22    3
# 5            0    0   0   62    3
# M0116048     0    0   0   25    3
# M0116150     0    0   0   21    0
# M0116300     0    0   0   16    0
# 6            0    0   0  107    2
# M0116127     0    0   0   25    0
# M0116306     0    0   0   36    1
# M0116311     0    0   0   46    1
# 7            0    0   0   61    2
# M0116047     0    0   0   13    1
# M0116165     0    0   0   20    0
# M0116166     0    0   0   28    1
# 8            0    0   0   66    4
# M0116024     0    0   0   20    1
# ...        ...  ...  ..  ...  ...
# M0116043     0    0   0   27    3
# M0116334     0    0   0   32    3
# 40           1    0   0   90   10
# M0115011     1    0   0   29    6
# M0116161     0    0   0   32    3
# M0116274     0    0   0   29    1
# 41           1    2   0   47    8
# M0116018     1    1   0   15    4
# M0116095     0    1   0   17    3
# M0116216     0    0   0   15    1
# 42           0    0   0   34    2
# M0116019     0    0   0    8    0
# M0116121     0    0   0   17    2
# M0116323     0    0   0    9    0
# 43           4    0   0   66   12
# M0116033     0    0   0   17    3
# M0116244     4    0   0   28    6
# M0116327     0    0   0   21    3
# 44           0    2   0   51   11
# M0116083     0    0   0    4    1
# M0116101     0    2   0   27    5
# M0116197     0    0   0   20    5
# 45           0    1   0   60    5
# M0116071     0    0   0   23    1
# M0116279     0    1   0   21    3
# M0116301     0    0   0   16    1
# 46           1    0   0   46    3
# M0116011     0    0   0   12    1
# M0116013     0    0   0   16    0
# M0116064     1    0   0   18    2
#
# [184 rows x 20 columns]

# %%
all = old_df.values.astype(np.float32)
all
# Out:
# array([[ 2.,  3.,  3., ...,  0., 54.,  4.],
#        [nan, nan, nan, ...,  0., 17.,  3.],
#        [nan, nan, nan, ...,  0., 14.,  0.],
#        ...,
#        [nan, nan, nan, ...,  0., 12.,  1.],
#        [nan, nan, nan, ...,  0., 16.,  0.],
#        [nan, nan, nan, ...,  0., 18.,  2.]], dtype=float32)

# %% [markdown]
# # 提出物評価と平均発現数（ラベル別）

# %%
# 全体 a11:良い a12:普通 a13:悪い
# 具体 a21:良い a22:普通 a23:悪い
# 工夫 a31:良い a32:普通 a33:悪い
# 適切 a41:良い a42:普通 a43:悪い

# グループの一行を抽出する
all_g = all[::4,:]

a11 = all_g[(all_g[:, 0] == 3)]
a12 = all_g[(all_g[:, 0] == 2)]
a13 = all_g[(all_g[:, 0] == 1)]

a21 = all_g[(all_g[:, 1] == 3)]
a22 = all_g[(all_g[:, 1] == 2)]
a23 = all_g[(all_g[:, 1] == 1)]

a31 = all_g[(all_g[:, 2] == 3)]
a32 = all_g[(all_g[:, 2] == 2)]
a33 = all_g[(all_g[:, 2] == 1)]

a41 = all_g[(all_g[:, 3] == 3)]
a42 = all_g[(all_g[:, 3] == 2)]
a43 = all_g[(all_g[:, 3] == 1)]

#　使用する列(0から)
index = [4,5,6,7,8,9,10,19,18]

print("全体： 同意--提案--質問--挨拶--報告--回答--転換--その他--計")
print("良い：",[round(np.mean(a11[:, i]), 1) for i in index])
print("普通：",[round(np.mean(a12[:, i]), 1) for i in index])
print("悪い：",[round(np.mean(a13[:, i]), 1) for i in index])



print("具体： 同意--提案--質問--挨拶--報告--回答--転換--その他--計")
print("良い：",[round(np.mean(a21[:, i]), 1) for i in index])
print("普通：",[round(np.mean(a22[:, i]), 1) for i in index])
print("悪い：",[round(np.mean(a23[:, i]), 1) for i in index])

print("工夫： 同意--提案--質問--挨拶--報告--回答--転換--その他--計")
print("良い：",[round(np.mean(a31[:, i]), 1) for i in index])
print("普通：",[round(np.mean(a32[:, i]), 1) for i in index])
print("悪い：",[round(np.mean(a33[:, i]), 1) for i in index])

print("適切： 同意--提案--質問--挨拶--報告--回答--転換--その他--計")
print("良い：",[round(np.mean(a41[:, i]), 1) for i in index])
print("普通：",[round(np.mean(a42[:, i]), 1) for i in index])
print("悪い：",[round(np.mean(a43[:, i]), 1) for i in index])
# Out:
# 全体： 同意--提案--質問--挨拶--報告--回答--転換--その他--計
# 良い： [20.1, 8.7, 6.7, 6.4, 8.0, 4.6, 2.6, 5.4, 62.6]
# 普通： [16.9, 10.2, 7.2, 6.4, 5.8, 5.3, 2.8, 5.2, 59.8]
# 悪い： [15.8, 11.5, 6.6, 6.0, 4.7, 4.3, 3.2, 6.4, 58.4]
# 具体： 同意--提案--質問--挨拶--報告--回答--転換--その他--計
# 良い： [19.6, 9.9, 7.5, 5.7, 7.8, 5.6, 2.3, 5.6, 64.0]
# 普通： [16.6, 10.2, 6.7, 6.8, 5.4, 4.6, 3.1, 5.1, 58.5]
# 悪い： [15.8, 11.2, 6.7, 5.9, 4.7, 4.4, 3.1, 6.4, 58.3]
# 工夫： 同意--提案--質問--挨拶--報告--回答--転換--その他--計
# 良い： [18.8, 9.4, 7.7, 6.8, 7.2, 5.4, 2.8, 6.0, 64.1]
# 普通： [17.2, 12.3, 6.8, 6.3, 5.6, 5.5, 2.5, 6.2, 62.5]
# 悪い： [14.9, 9.1, 6.1, 5.6, 4.4, 3.1, 3.4, 4.9, 51.6]
# 適切： 同意--提案--質問--挨拶--報告--回答--転換--その他--計
# 良い： [17.8, 10.6, 6.3, 5.9, 7.8, 4.8, 2.7, 4.9, 60.8]
# 普通： [15.9, 10.2, 7.0, 6.6, 4.8, 4.9, 3.0, 5.8, 58.2]
# 悪い： [18.7, 11.4, 7.2, 5.6, 5.2, 4.3, 3.0, 6.7, 62.1]

# %% [markdown]
# # 提出物評価と発言数との相関係数

# %%
# 全体 y1
# 具体 y2
# 工夫 y3
# 適切 y4

# グループの一行を抽出する
all_g = all[::4,:]

#　使用する列(0から)
index = [4,5,6,7,8,9,10,18]

y1 = all_g[:,0]
y2 = all_g[:,1]
y3 = all_g[:,2]
y4 = all_g[:,3]

print("具体： 同意---提案---質問---挨拶---報告---回答---転換---全発言")
print("全体：",[round(np.corrcoef(all_g[:, i], y1)[0,1],2) for i in index])
print("具体：",[round(np.corrcoef(all_g[:, i], y2)[0,1],2) for i in index])
print("工夫：",[round(np.corrcoef(all_g[:, i], y3)[0,1],2) for i in index])
print("適切：",[round(np.corrcoef(all_g[:, i], y4)[0,1],2) for i in index])
# Out:
# 具体： 同意---提案---質問---挨拶---報告---回答---転換---全発言
# 全体： [0.17, -0.16, 0.04, 0.09, 0.37, 0.08, -0.12, 0.07]
# 具体： [0.16, -0.08, 0.08, -0.0, 0.37, 0.14, -0.13, 0.09]
# 工夫： [0.18, 0.02, 0.18, 0.2, 0.38, 0.29, -0.12, 0.24]
# 適切： [-0.02, -0.04, -0.09, 0.03, 0.32, 0.05, -0.06, -0.01]

# %% [markdown]
# # 提出物評価と発言数の偏りとの相関係数

# %%
test = all

index = [4,5,6,7,8,9,10,18]
for i in index:
    for g in range(46):
        aa = [test[g*4+1][i],test[g*4+2][i],test[g*4+3][i]]
        if np.std(aa) == 0 or np.mean(aa) == 0:
            test[g*4][i] = 0.0
        else:
            test[g*4][i] = np.std(aa)/np.mean(aa)


            
all_g = test[::4,:]
y1 = all_g[:,0]
y2 = all_g[:,1]
y3 = all_g[:,2]
y4 = all_g[:,3]

# np.set_printoptions(threshold=np.inf)
# np.set_printoptions(suppress=True)

print("具体： 同意---提案---質問---挨拶---報告---回答---転換---全発言")
print("全体：",[round(np.corrcoef(all_g[:, i], y1)[0,1],2) for i in index])
print("具体：",[round(np.corrcoef(all_g[:, i], y2)[0,1],2) for i in index])
print("工夫：",[round(np.corrcoef(all_g[:, i], y3)[0,1],2) for i in index])
print("適切：",[round(np.corrcoef(all_g[:, i], y4)[0,1],2) for i in index])
# Out:
# 具体： 同意---提案---質問---挨拶---報告---回答---転換---全発言
# 全体： [-0.14, 0.02, -0.13, -0.09, -0.25, 0.15, -0.15, -0.03]
# 具体： [-0.22, -0.03, -0.0, 0.08, -0.27, 0.17, -0.12, -0.07]
# 工夫： [-0.11, -0.05, -0.18, -0.2, -0.24, -0.04, -0.21, -0.07]
# 適切： [-0.06, -0.06, 0.08, 0.1, -0.35, 0.26, -0.18, -0.11]

# %%
# 発言数-平均との差
# print(np.round(al/np.mean(al,axis=0),2))
# al_1 = np.round(al/np.mean(al,axis=0),2)
# print(al_1)
# 発言割合
# print(np.round(al/al[:,-1:],2))
# al_2 = np.round(al/al[:,-1:],2)
# print(al_2)
# 発言割合-平均との差
# print(np.round((al/al[:,-1:])/(np.sum(al,axis=0)/np.sum(al[:,-1])),2))
# al_3 = np.round((al/al[:,-1:])/(np.sum(al,axis=0)/np.sum(al[:,-1])),2)
# print(al_3)
